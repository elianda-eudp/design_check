# %%
from docx import Document

def table(num,document):

    row1_list = []
    row_content = []
    """获取第一个表格内容"""
    table = document.tables[num]
    """获取第一行标题"""
    row_1 = table.row_cells(0)
    """将第一行标题提取出来"""
    for row in table.rows:
        for cell1 in row.cells:
    #            print(cell.text)
            for cell2 in row_1:
#                print(cell2.text)
                if cell1.text == cell2.text:
                    key = cell1.text                 
                    row1_list.append(key)
#                    print(key)
                    break
            else:
                """将内容提取出来"""
                value = cell1.text
                new_value = value.replace('\n', ' ')
                row_content.append(new_value)

    dict1={}

    for i in range(len(row1_list)): # 循环标题列表
        dict2={}
        a_list=[j for j in range(i,len(row_content),len(row1_list)) ] # 循环内容列表
        for k in range(len(a_list)):  
            dict2[row1_list[i]+str(k)] = row_content[a_list[k]] # 构造内层字典
        dict1[row1_list[i]] = dict2     # 构造整体字典
              
#    print(dict1)
    return dict1

# %%
def head3_index_get(paras,max_i,min_i):
    head3_index_list=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Heading 3':
            head3_index_list.append(i)
    return head3_index_list

def head4_index_get(paras,max_i,min_i):
    head4_index_list=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Heading 4':
            head4_index_list.append(i)
    return head4_index_list

def print_con(paras,index):
    for i in index:
        print("    " + paras[i].text)
        
def normal_get(paras,max_i,min_i):
    list_normat=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Normal':
            list_normat.append(paras[i].text)
    return list_normat

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jan 12 09:55:52 2018

@author: user
"""

from docx import Document
import json
def main(doc='../../../project_data/doc/理财监管新规数据库优化11.9.docx'):
    document = Document(doc)
    paras = document.paragraphs
    lcount = []  # 存储所有段落的对象 
    tables=0
    
    
  
    for i in range(len(paras)):
        if paras[i].style.name == 'Heading 2':
            lcount.append(i)
#            print(paras[i].text)
#    print(len(lcount))      
    # 提取每一段的数据
    for i in range(len(lcount)):
        if i>= len(lcount)-1:
            bx = lcount[i]
        else:
            bx = lcount[i+1]
        ax = lcount[i]
        head3_index_list=head3_index_get(paras,bx,ax)
        #print(paras[ax].text)
        
        #print_con(paras,head3_index_list)
        for j in range(len(head3_index_list)):
            if j >= len(head3_index_list)-1:
                head3_max = bx
            else:
                head3_max = head3_index_list[j+1]
            head3_min = head3_index_list[j]
            head3_dict={}
        
            head4_index_list=head4_index_get(paras,head3_max,head3_min)
            head4_dict={}
            #print(paras[head3_min].text)
            #print_con(paras,head4_index_list)
            for z in range(len(head4_index_list)):
                if z>= len(head4_index_list)-1:
                    head4_max = head3_max
                else:
                    head4_max = head4_index_list[z+1]
                head4_min = head4_index_list[z]
                #print(paras[head4_min].text)
                if '字段' in str(paras[head4_min].text) :
                    #for k in range(head4_min,head4_max):
                     #   print(paras[k].text)
                    table_dict=table(tables,document)
                    tables+=1
                    head4_dict[paras[head4_min].text]=table_dict
                else:
                    normal=normal_get(paras,head4_max,head4_min)
                    head4_dict[paras[head4_min].text]=''.join(normal).replace('\u3000', ' ')
           
            head3_dict[paras[head3_min].text]=head4_dict
            
            table_name=paras[head3_min].text.split('（')[0]
            file_name='../../../project_data/tables_json/'+table_name+'.json'
            #print(file_name)
            with open(file_name,'w+') as f:
                str_data = json.dumps(head3_dict)
                print(head3_dict)
                f.write(str_data)

# %%
main()
# Out:
# {'gf_asset_info（底层资产信息表）': {'说明': '该表存储资产管理系统内维护的用作资产标的物的资产记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_ASSET_INFO主键字段：asset_code，prj_code', '索引': '', '字段': {'列名': {'列名0': 'prj_code', '列名1': 'asset_code', '列名2': 'asset_name', '列名3': 'asset_begin_date', '列名4': 'asset_end_date', '列名5': 'invest_amt', '列名6': 'profit_rate', '列名7': 'asset_recommendation_branch'}, '中文名称': {'中文名称0': '项目编码', '中文名称1': '资产编码', '中文名称2': '资产名称', '中文名称3': '资产起始日期', '中文名称4': '资产到期日期', '中文名称5': '拟投资金额', '中文名称6': '持有期间收益', '中文名称7': '资产推荐分行'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'number', '类型6': 'number', '类型7': 'varchar2'}, '长度': {'长度0': '36', '长度1': '36', '长度2': '200', '长度3': '8', '长度4': '8', '长度5': '22', '长度6': '22', '长度7': '8'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'Y'}, '备注': {'备注0': '项目编码', '备注1': '资产编码', '备注2': '资产名称,也称作最终投资标的', '备注3': '资产起始日期', '备注4': '资产到期日期', '备注5': '拟投资金额', '备注6': '持有期间收益(%)', '备注7': '资产推荐分行'}}}}
# {'gf_prod_asset_rel（理财产品标的资产信息表）': {'说明': '该表存储资产管理系统内维护的用作资产标的物的资产记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_PROD_ASSET_REL主键字段：asset_code，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'asset_code', '列名2': 'asset_name', '列名3': 'latest_modify_date', '列名4': 'latest_modify_time', '列名5': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '资产编码', '中文名称2': '资产名称', '中文名称3': '最后修改日期', '中文名称4': '最后修改时间', '中文名称5': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'varchar2'}, '长度': {'长度0': '10', '长度1': '20', '长度2': '200', '长度3': '8', '长度4': '6', '长度5': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品代码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4） ', '备注1': '资产编码', '备注2': '资产名称,也称作最终投资标的', '备注3': '最后修改日期', '备注4': '最后修改时间', '备注5': '最后操作员'}}}}
# {'gf_prod_asset_mutual_info（理财产品资管协议表）': {'说明': '理财产品资管协议表', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_ASSET_MUTUAL_INFO主键字段：prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'manage_mode', '列名2': 'agent_code', '列名3': 'raise_type', '列名4': 'interest_rate', '列名5': 'pay_period', '列名6': 'pay_period_type', '列名7': 'pay_feature', '列名8': 'first_pay_date', '列名9': 'busi_day_rule', '列名10': 'even_cost_asset_type'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '管理方式', '中文名称2': '托管行', '中文名称3': '募集方式', '中文名称4': '利率类型', '中文名称5': '付息周期', '中文名称6': '付息周期跨度', '中文名称7': '付息特征', '中文名称8': '首次付息日', '中文名称9': '营业日准则', '中文名称10': '保本产品成本户资产类型'}, '类型': {'类型0': 'varchar2', '类型1': 'char', '类型2': 'varchar2', '类型3': 'char', '类型4': 'char', '类型5': 'number', '类型6': 'char', '类型7': 'char', '类型8': 'varchar2', '类型9': 'char', '类型10': 'varchar2'}, '长度': {'长度0': '10', '长度1': '1', '长度2': '30', '长度3': '1', '长度4': '2', '长度5': '22', '长度6': '1', '长度7': '2', '长度8': '8', '长度9': '2', '长度10': '16'}, '可空': {'可空0': 'N', '可空1': 'Y', '可空2': 'Y', '可空3': 'Y', '可空4': 'Y', '可空5': 'Y', '可空6': 'Y', '可空7': 'Y', '可空8': 'Y', '可空9': 'Y', '可空10': 'Y'}, '备注': {'备注0': '理财产品代码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4） ', '备注1': '管理方式 S-单独管理[固定]，C-集合管理', '备注2': '托管行 ', '备注3': '募集方式 1-公募 2-私募', '备注4': '利率类型 01-挂钩标的浮动,02-自由报价（默认）,03-固定利率', '备注5': '付息周期', '备注6': '付息周期跨度 Y-年 M-月 D-日', '备注7': '付息特征:01-起息日向后02-到期日向前03-首次付息日向后04-不调整', '备注8': '首次付息日 如果付息特征为03，则维护首次付息日', '备注9': '营业日准则：01-向前调整 02-向后调整 03-调整的向后调整 04-不调整', '备注10': '保本产品成本户资产类型'}}}}
# {'gf_prj_info（项目信息表）': {'说明': '该表记录资产管理系统运作资产投资的项目信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：262144  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PRJ_INFO主键字段：prj_code', '索引': '', '字段': {'列名': {'列名0': 'prj_code', '列名1': 'prj_name', '列名2': 'prj_invest_type_my', '列名3': 'prj_invest_type_cbrc', '列名4': 'prj_invest_type_pbc', '列名5': 'prj_manage_fee_rate', '列名6': 'prj_adviser_fee_rate', '列名7': 'prj_other_fee_rate', '列名8': 'prj_sum_fee_rate', '列名9': 'invest_type_per', '列名10': 'cooperation_mode', '列名11': 'prj_trustee_fee_rate', '列名12': 'prj_begin_date', '列名13': 'prj_end_date', '列名14': 'prj_status', '列名15': 'prj_research_staff', '列名16': 'prj_type'}, '中文名称': {'中文名称0': '项目编码', '中文名称1': '项目名称', '中文名称2': '项目投资类型', '中文名称3': '项目投资类型', '中文名称4': '项目投资类型', '中文名称5': '项目信托报酬或管理费率', '中文名称6': '项目投资顾问费率', '中文名称7': '项目其他费率', '中文名称8': '项目费率合计', '中文名称9': '投资资产种类及比例', '中文名称10': '合作模式', '中文名称11': '项目托管费率', '中文名称12': '项目起始日期', '中文名称13': '项目终止日期', '中文名称14': '项目状态', '中文名称15': '项目研发人', '中文名称16': '项目类别'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'number', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'number', '类型6': 'number', '类型7': 'number', '类型8': 'number', '类型9': 'varchar2', '类型10': 'varchar2', '类型11': 'number', '类型12': 'varchar2', '类型13': 'varchar2', '类型14': 'varchar2', '类型15': 'varchar2', '类型16': 'char'}, '长度': {'长度0': '36', '长度1': '200', '长度2': '22', '长度3': '20', '长度4': '20', '长度5': '22', '长度6': '22', '长度7': '22', '长度8': '22', '长度9': '200', '长度10': '20', '长度11': '22', '长度12': '8', '长度13': '8', '长度14': '10', '长度15': '11', '长度16': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'Y', '可空3': 'Y', '可空4': 'Y', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N', '可空9': 'Y', '可空10': 'Y', '可空11': 'N', '可空12': 'N', '可空13': 'N', '可空14': 'N', '可空15': 'N', '可空16': 'N'}, '备注': {'备注0': '项目编码', '备注1': '项目名称', '备注2': '项目投资类型（我行统计口径）', '备注3': '项目投资类型（银监会统计口径）', '备注4': '项目投资类型（人行统计口径）', '备注5': '项目信托报酬或管理费率%', '备注6': '项目投资顾问费率%', '备注7': '项目其他费率%', '备注8': '项目费率合计%（不含投资顾问费）', '备注9': '投资资产种类及比例', '备注10': '合作模式', '备注11': '项目托管费率%', '备注12': '项目起始日期', '备注13': '项目终止日期', '备注14': '项目状态', '备注15': '项目研发人', '备注16': '项目类别 C-通道，T-自定义，B母资管'}}}}
# {'gf_prod_prj_rel（理财产品投资项目表）': {'说明': '该表存储理财产品与投资项目的信息', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_PRJ_REL主键字段：prod_code，prj_code', '索引': '', '字段': {'列名': {'列名0': 'prj_code', '列名1': 'prod_code', '列名2': 'latest_modify_date', '列名3': 'latest_modify_time', '列名4': 'latest_oper_code', '列名5': 'pre_prj_code'}, '中文名称': {'中文名称0': '项目编码', '中文名称1': '理财产品编码', '中文名称2': '最后修改日期', '中文名称3': '最后修改时间', '中文名称4': '最后操作员', '中文名称5': '前置项目代码'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'varchar2'}, '长度': {'长度0': '36', '长度1': '10', '长度2': '8', '长度3': '6', '长度4': '11', '长度5': '36'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'Y'}, '备注': {'备注0': '项目编码', '备注1': '通过视图查询品牌信息，理财产品代码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注2': '最后修改日期', '备注3': '最后修改时间', '备注4': '最后操作员', '备注5': '前置项目代码'}}}}
# {'gf_prod_register_info（理财产品申报登记信息表）': {'说明': '该表存储行内发行的理财产品的申报登记类信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_REGISTER_INFO主键字段：prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'register_code', '列名2': 'issue_branch_code', '列名3': 'cust_risk_preference', '列名4': 'prod_manage_mode', '列名5': 'actual_manager_name', '列名6': 'pricing_method', '列名7': 'internal_custodian_name', '列名8': 'internal_custodian_code', '列名9': 'overseas_custodian', '列名10': 'overseas_custodian_name', '列名11': 'prod_invest_area', '列名12': 'amt_invest_area', '列名13': 'issue_terminate_flag', '列名14': 'redemption_flag', '列名15': 'fbop_code', '列名16': 'bank_item_code', '列名17': 'bank_item_name', '列名18': 'principal_recv_type', '列名19': 'profit_recv_type', '列名20': 'raise_currency', '列名21': 'principal_currency', '列名22': 'profit_currency', '列名23': 'prod_period', '列名24': 'is_expected_profit_rate', '列名25': 'is_cal_basis', '列名26': 'cust_actual_profit_rate', '列名27': 'serve_model', '列名28': 'prod_incr_trust_flag', '列名29': 'prod_incr_trust_organ_type', '列名30': 'prod_incr_trust_type', '列名31': 'prod_approver_name', '列名32': 'prod_approver_cert_code', '列名33': 'prod_designer_name', '列名34': 'prod_designer_cert_code', '列名35': 'invest_manager_name', '列名36': 'invest_manager_cert_code', '列名37': 'cont_person_name', '列名38': 'cont_person_phone', '列名39': 'cont_person_mobile', '列名40': 'cont_person_email', '列名41': 'prod_asset_conf_type', '列名42': 'r_cust_type', '列名43': 'symbiosis_mode', '列名44': 'symbiosis_organ_name', '列名45': 'invest_type_per', '列名46': 'struct_prod_asset', '列名47': 'invest_asset_type', '列名48': 'is_struct_prod', '列名49': 'lay_type', '列名50': 'profit_level_info', '列名51': 'open_mode', '列名52': 'open_period_rule', '列名53': 'other_open_period_rule', '列名54': 'no_rule_open_info', '列名55': 'first_open_date', '列名56': 'holiday_open_flag', '列名57': 'ave_open_period', '列名58': 'open_operation', '列名59': 'open_opera_info', '列名60': 'issue_num'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '申报登记编码', '中文名称2': '发行机构代码', '中文名称3': '投资者风险偏好', '中文名称4': '产品管理模式', '中文名称5': '实际管理人名称', '中文名称6': '产品定价方式', '中文名称7': '境内托管机构名称', '中文名称8': '境内托管机构代码', '中文名称9': '境外托管机构国别', '中文名称10': '境外托管机构名称', '中文名称11': '产品投资国家或地区', '中文名称12': '资金投向地区', '中文名称13': '发行机构提前终止权标识', '中文名称14': '客户赎回权标识', '中文名称15': '金融许可证号', '中文名称16': '明细科目编号', '中文名称17': '明细科目名称', '中文名称18': '投资本金到账日', '中文名称19': '投资收益到账日', '中文名称20': '募集币种', '中文名称21': '兑付本金币种', '中文名称22': '兑付收益币种', '中文名称23': '产品期限', '中文名称24': '是否有预期收益率', '中文名称25': '是否有收益率测算依据', '中文名称26': '客户端实际年化收益率', '中文名称27': '理财业务服务模式', '中文名称28': '产品增信标识', '中文名称29': '产品增信机构类型', '中文名称30': '产品增信形式', '中文名称31': '产品审批人姓名', '中文名称32': '产品审批人身份证号', '中文名称33': '产品设计人姓名', '中文名称34': '产品设计人身份证号', '中文名称35': '投资经理姓名', '中文名称36': '投资经理身份证号', '中文名称37': '业务联络人姓名', '中文名称38': '业务联络人座机', '中文名称39': '业务联络人手机', '中文名称40': '业务联络人邮箱', '中文名称41': '产品资产配置方式', '中文名称42': '投资者类型', '中文名称43': '合作模式', '中文名称44': '合作机构名称', '中文名称45': '投资资产种类及比例', '中文名称46': '结构性产品挂钩标的', '中文名称47': '投资资产类型', '中文名称48': '是否为结构化（分级）产品', '中文名称49': '层级类别', '中文名称50': '收益率分档情况说明', '中文名称51': '开放模式', '中文名称52': '规律开放周期', '中文名称53': '其他规律开放周期', '中文名称54': '无规律开放说明', '中文名称55': '首次开放周期起始日', '中文名称56': '节假日是否开放', '中文名称57': '平均开放次数（年化）', '中文名称58': '开放期业务', '中文名称59': '开放期业务说明', '中文名称60': '品牌期次'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'varchar2', '类型6': 'varchar2', '类型7': 'varchar2', '类型8': 'varchar2', '类型9': 'varchar2', '类型10': 'varchar2', '类型11': 'varchar2', '类型12': 'varchar2', '类型13': 'varchar2', '类型14': 'varchar2', '类型15': 'varchar2', '类型16': 'varchar2', '类型17': 'varchar2', '类型18': 'varchar2', '类型19': 'varchar2', '类型20': 'varchar2', '类型21': 'varchar2', '类型22': 'varchar2', '类型23': 'varchar2', '类型24': 'varchar2', '类型25': 'varchar2', '类型26': 'number', '类型27': 'varchar2', '类型28': 'varchar2', '类型29': 'varchar2', '类型30': 'varchar2', '类型31': 'varchar2', '类型32': 'varchar2', '类型33': 'varchar2', '类型34': 'varchar2', '类型35': 'var ...
# {'gf_prod_brand_info（理财产品品牌信息表）': {'说明': '该表存储用于发行理财产品的产品品牌信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_BRAND_INFO主键字段：brand_code', '索引': '', '字段': {'列名': {'列名0': 'brand_code', '列名1': 'brand_name', '列名2': 'prod_issue_serial', '列名3': 'issue_num', '列名4': 'valid_status', '列名5': 'latest_modify_date', '列名6': 'latest_modify_time', '列名7': 'latest_oper_code', '列名8': 'brand_desc'}, '中文名称': {'中文名称0': '品牌代码', '中文名称1': '品牌名称', '中文名称2': '年度期次', '中文名称3': '该品牌累计发行期次', '中文名称4': '状态', '中文名称5': '最后修改日期', '中文名称6': '最后修改时间', '中文名称7': '最后操作员', '中文名称8': '品牌描述'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'number', '类型4': 'char', '类型5': 'varchar2', '类型6': 'varchar2', '类型7': 'varchar2', '类型8': 'varchar2'}, '长度': {'长度0': '2', '长度1': '60', '长度2': '4', '长度3': '22', '长度4': '1', '长度5': '8', '长度6': '6', '长度7': '11', '长度8': '1000'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'Y'}, '备注': {'备注0': '品牌代码', '备注1': '品牌名称', '备注2': '年度期次 每年从01、02开始往后排，到9999', '备注3': '该品牌累计发行期次,总期次', '备注4': '状态1- 正常 2- 无效', '备注5': '最后修改日期', '备注6': '最后修改时间', '备注7': '最后操作员', '备注8': '品牌描述'}}}}
# {'gf_prod_issue_area（理财产品发售区域信息）': {'说明': '该表存储理财产品发售区域信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_ISSUE_AREA主键字段：province_branch_code，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'province_branch_code', '列名2': 'latest_modify_date', '列名3': 'latest_modify_time', '列名4': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '一级分行', '中文名称2': '最后修改日期', '中文名称3': '最后修改时间', '中文名称4': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2'}, '长度': {'长度0': '10', '长度1': '10', '长度2': '8', '长度3': '6', '长度4': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品代码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '一级分行', '备注2': '最后修改日期', '备注3': '最后修改时间', '备注4': '最后操作员'}}}}
# {'ta_retailer_limit_ctl（理财产品销售商额度信息）': {'说明': '该表存储产品销售商额度信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_TA_RETAILER_LIMIT_CTL主键字段：end_date，begin_date，limit_type，retailer_code，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'retailer_code', '列名2': 'begin_date', '列名3': 'end_date', '列名4': 'retailer_sum_limit', '列名5': 'retailer_selling_limit', '列名6': 'limit_type', '列名7': 'is_manage'}, '中文名称': {'中文名称0': '理财产品代码', '中文名称1': '销售商代码', '中文名称2': '开始日期', '中文名称3': '结束日期', '中文名称4': '总额度', '中文名称5': '可销售额度', '中文名称6': '额度类型', '中文名称7': '是否管理'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'number', '类型5': 'number', '类型6': 'char', '类型7': 'char'}, '长度': {'长度0': '10', '长度1': '10', '长度2': '8', '长度3': '8', '长度4': '22', '长度5': '22', '长度6': '1', '长度7': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N'}, '备注': {'备注0': '理财产品代码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '销售商代码', '备注2': '开始日期', '备注3': '结束日期', '备注4': '总额度', '备注5': '可销售额度', '备注6': '额度类型:1-认购 2-申购', '备注7': '是否管理:0-否 1-是'}}}}
# {'gf_limit_ctl（理财产品直销系统额度信息）': {'说明': '理财产品直销系统额度信息', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_LIMIT_CTL1主键字段：organ_code，prod_code，end_date，begin_date，channel', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'organ_code', '列名2': 'channel', '列名3': 'begin_date', '列名4': 'end_date', '列名5': 'wait_sell_limit', '列名6': 'can_sell_limit', '列名7': 'sum_order_limit', '列名8': 'can_order_limit', '列名9': 'sum_buy_limit', '列名10': 'can_buy_limit', '列名11': 'sum_purchase_limit', '列名12': 'can_purchase_limit', '列名13': 'is_up_limit'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '机构代码', '中文名称2': '渠道', '中文名称3': '开始日期', '中文名称4': '结束日期', '中文名称5': '待销额度', '中文名称6': '在销额度', '中文名称7': '总预约额度', '中文名称8': '可预约额度', '中文名称9': '总认购额度', '中文名称10': '可认购额度', '中文名称11': '总申购额度', '中文名称12': '可申购额度', '中文名称13': '是否向上级取额度'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'number', '类型6': 'number', '类型7': 'number', '类型8': 'number', '类型9': 'number', '类型10': 'number', '类型11': 'number', '类型12': 'number', '类型13': 'char'}, '长度': {'长度0': '10', '长度1': '8', '长度2': '2', '长度3': '8', '长度4': '8', '长度5': '22', '长度6': '22', '长度7': '22', '长度8': '22', '长度9': '22', '长度10': '22', '长度11': '22', '长度12': '22', '长度13': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N', '可空9': 'N', '可空10': 'N', '可空11': 'N', '可空12': 'N', '可空13': 'N'}, '备注': {'备注0': '理财产品代码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '机构代码', '备注2': '渠道', '备注3': '开始日期', '备注4': '结束日期', '备注5': '待销额度', '备注6': '在销额度', '备注7': '总预约额度', '备注8': '可预约额度', '备注9': '总认购额度', '备注10': '可认购额度', '备注11': '总申购额度', '备注12': '可申购额度', '备注13': '是否向上级取额度: 0-否 1-是 '}}}}
# {'gf_prod_base_info（理财产品基本参数表）': {'说明': '', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_BASE_INFO主键字段：prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'prod_name', '列名2': 'prod_name_suffix', '列名3': 'profit_type', '列名4': 'prod_oper_model', '列名5': 'prod_risk_level', '列名6': 'is_cont_prod', '列名7': 'is_need_cont_prod', '列名8': 'is_auto_balance', '列名9': 'currency', '列名10': 'accounting_flag', '列名11': 'is_night_market', '列名12': 'fee_prov_flag', '列名13': 'is_quanto', '列名14': 'prod_begin_date', '列名15': 'prod_end_date', '列名16': 'prod_duration_days', '列名17': 'mouth_profit_date', '列名18': 'prod_status', '列名19': 'cust_type', '列名20': 'is_white_list', '列名21': 'is_point', '列名22': 'is_pos', '列名23': 'is_cust_prop', '列名24': 'vip_grade', '列名25': 'highest_investment', '列名26': 'lowest_investment', '列名27': 'multi_money', '列名28': 'hold_money', '列名29': 'corp_highest_investment', '列名30': 'corp_lowest_investment', '列名31': 'corp_multi_money', '列名32': 'corp_hold_money', '列名33': 'dividend_flag', '列名34': 'default_dividend_flag', '列名35': 'is_dividend_alter', '列名36': 'is_asset_prove', '列名37': 'is_order_auto_buy', '列名38': 'is_duration', '列名39': 'is_date_invest', '列名40': 'transition_flag', '列名41': 'is_pledge', '列名42': 'profit_handle_flag', '列名43': 'sell_fee_type', '列名44': 'prod_control_fee_rate', '列名45': 'predict_highest_profit', '列名46': 'predict_lowest_profit', '列名47': 'overfulfil_profit', '列名48': 'prod_profit_rate', '列名49': 'prod_recom_rate', '列名50': 'other_rate', '列名51': 'day_count_basis', '列名52': 'head_office_mag_fee', '列名53': 'fel_mag_fee', '列名54': 'nonrecurring_charge', '列名55': 'prod_oper_code', '列名56': 'latest_modify_date', '列名57': 'latest_modify_time', '列名58': 'latest_oper_code', '列名59': 'prod_code_flag', '列名60': 'cancel_flag', '列名61': 'prod_manager_code', '列名62': 'head_auto_balance_flag', '列名63': 'share_channel', '列名64': 'share_prov', '列名65': 'purchase_channel', '列名66': 'purchase_prov'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '产品名称', '中文名称2': '产品名称后缀', '中文名称3': '产品收益类型', '中文名称4': '产品运作模式', '中文名称5': '产品风险等级', '中文名称6': '是否是续接产品', '中文名称7': '是否需要被续接', '中文名称8': '是否自主平衡', '中文名称9': '币种', '中文名称10': '会计核算方式', '中文名称11': '夜市标志', '中文名称12': '计提方式', '中文名称13': '是否结构性理财', '中文名称14': '理财产品成立日期', '中文名称15': '理财产品到期日期', '中文名称16': '产品存续期限(天)', '中文名称17': '每月收益结转日', '中文名称18': '产品状态', '中文名称19': '客户类型', '中文名称20': '是否设置黑白名单', '中文名称21': '是否积分产品', '中文名称22': '是否为POS理财产品', '中文名称23': '是否控制客户行内属性:0-否；1-是', '中文名称24': 'VIP等级', '中文名称25': '个人客户最高投资额', '中文名称26': '个人客户最低投资额', '中文名称27': '个人客户投资倍增金额', '中文名称28': '个人客户最低持有份额', '中文名称29': '机构客户最大投资额', '中文名称30': '机构客户最低投资额', '中文名称31': '机构客户倍增金额', '中文名称32': '机构客户最低持有份额', '中文名称33': '分红方式', '中文名称34': '默认分红方式', '中文名称35': '是否允许分红方式变更', '中文名称36': '是否允许财产证明', '中文名称37': '是否预约自动认购', '中文名称38': '是否有存续周期', '中文名称39': '定投业务开办标志', '中文名称40': '转换标志', '中文名称41': '是否允许质押', '中文名称42': '收益计算标识', '中文名称43': '销售手续费类型', '中文名称44': '产品托管费率', '中文名称45': '预计客户最高年化收益率', '中文名称46': '预计客户最低年化收益率', '中文名称47': '超额留存收益率', '中文名称48': '产品投资收益率', '中文名称49': '产品推荐费率', '中文名称50': '其他费率 ', '中文名称51': '计息基础', '中文名称52': '总行管理费率', '中文名称53': '浮动管理费率', '中文名称54': '一次性费用', '中文名称55': '产品研发人', '中文名称56': '最后修改日期', '中文名称57': '最后修改时间', '中文名称58': '最后操作员', '中文名称59': '产品标识', '中文名称60': '购买期最后一天允许撤单', '中文名称61': '', '中文名称62': '总行代为操作的分行自主平衡产品标识', '中文名称63': '认购期共享渠道', '中文名称64': '认购期共享省', '中文名称65': '申购共享渠道', '中文名称66': '申购共享省'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'char', '类型6': 'char', '类型7': 'char', '类型8': 'char', '类型9': 'varchar2', '类型10': 'char', '类型11': 'char', '类型12': 'char', '类型13': 'char', '类型14': 'varchar2', '类型15': 'varchar2', '类型16': 'varchar2', '类型17': 'number', '类型18': 'char', '类型19': 'char', '类型20': 'char', '类型21': 'char', '类型22': 'char', '类型23': 'char', '类型24': 'char', '类型25': 'number', '类型26': 'number', '类型27': 'number', '类型28': 'number', '类型29': 'number', '类型30': 'number', '类型31': 'number', '类型32': 'number', '类型33': 'char', '类型34': ...
# {'gf_prod_organ_white_list（理财产品机构黑白名单信息表）': {'说明': '该表用于储存理财产品运营限制信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_ORGAN_WHITE_LIST主键字段：organ_code，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'list_type', '列名2': 'organ_code', '列名3': 'organ_level', '列名4': 'use_status', '列名5': 'latest_modify_date', '列名6': 'latest_modify_time', '列名7': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '名单类型', '中文名称2': '机构代码', '中文名称3': '机构级别', '中文名称4': '状态', '中文名称5': '最后修改日期', '中文名称6': '最后修改时间', '中文名称7': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'char', '类型2': 'varchar2', '类型3': 'char', '类型4': 'char', '类型5': 'varchar2', '类型6': 'varchar2', '类型7': 'varchar2'}, '长度': {'长度0': '10', '长度1': '1', '长度2': '8', '长度3': '1', '长度4': '1', '长度5': '8', '长度6': '6', '长度7': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'Y', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '名单类型:1-黑名单,2-白名单 ', '备注2': '机构代码', '备注3': '机构级别:0-全国中心 1-省级 2-地区 3-市,县级 4-支局所', '备注4': '状态 1- 启用 2- 停用', '备注5': '最后修改日期', '备注6': '最后修改时间', '备注7': '最后操作员'}}}}
# {'gf_prod_cust_white_list（理财产品客户黑白名单信息表）': {'说明': '该表用于储存理财产品运营限制信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_CUST_WHITE_LIST主键字段：prod_code，ta_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'list_type', '列名2': 'ta_code', '列名3': 'use_status', '列名4': 'latest_modify_date', '列名5': 'latest_modify_time', '列名6': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '名单类型', '中文名称2': 'ta账号', '中文名称3': '状态', '中文名称4': '最后修改日期', '中文名称5': '最后修改时间', '中文名称6': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'char', '类型2': 'varchar2', '类型3': 'char', '类型4': 'varchar2', '类型5': 'varchar2', '类型6': 'varchar2'}, '长度': {'长度0': '10', '长度1': '1', '长度2': '30', '长度3': '1', '长度4': '8', '长度5': '6', '长度6': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '名单类型:1-黑名单,2-白名单 ', '备注2': 'ta账号', '备注3': '状态 1- 启用 2- 停用', '备注4': '最后修改日期', '备注5': '最后修改时间', '备注6': '最后操作员'}}}}
# {'gf_prod_point_info（理财产品积分信息表）': {'说明': '如果某只理财产品的认购、预约等交易，要求有特定积分的客户才可以做，在此表存储该理财产品所要求的客户积分限额。', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_POINT_INFO主键字段：prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'buy_point_quot', '列名2': 'order_point_quot', '列名3': 'latest_modify_date', '列名4': 'latest_modify_time', '列名5': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '购买积分限额', '中文名称2': '预约积分限额', '中文名称3': '最后修改日期', '中文名称4': '最后修改时间', '中文名称5': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'number', '类型2': 'number', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'varchar2'}, '长度': {'长度0': '10', '长度1': '22', '长度2': '22', '长度3': '8', '长度4': '6', '长度5': '11'}, '可空': {'可空0': 'N', '可空1': 'Y', '可空2': 'Y', '可空3': 'N', '可空4': 'N', '可空5': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '购买积分限额', '备注2': '预约积分限额', '备注3': '最后修改日期', '备注4': '最后修改时间', '备注5': '最后操作员'}}}}
# {'gf_prod_pos_parameters（理财POS参数表）': {'说明': '该表用来存储POS理财产品的参数', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_POS_PARAMETERS主键字段：pos_top_rate，pos_exp_days', '索引': '', '字段': {'列名': {'列名0': 'pos_exp_days', '列名1': 'pos_top_rate'}, '中文名称': {'中文名称0': 'POS入账有效天数', '中文名称1': 'POS入账金额最高理财申购金额比率'}, '类型': {'类型0': 'number', '类型1': 'number'}, '长度': {'长度0': '22', '长度1': '22'}, '可空': {'可空0': 'N', '可空1': 'N'}, '备注': {'备注0': 'POS入账有效天数', '备注1': 'POS入账金额最高理财申购金额比率'}}}}
# {'gf_prod_cust_prop（理财产品客户行内属性）': {'说明': '该表存储理财产品发售客户群信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_CUST_PROP主键字段：prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'prop_code', '列名2': 'rel_type', '列名3': 'valid_status', '列名4': 'latest_modify_date', '列名5': 'latest_modify_time', '列名6': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品代码', '中文名称1': '属性编码', '中文名称2': '与或关系类型', '中文名称3': '状态', '中文名称4': '最后修改日期', '中文名称5': '最后修改时间', '中文名称6': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'char', '类型3': 'char', '类型4': 'varchar2', '类型5': 'varchar2', '类型6': 'varchar2'}, '长度': {'长度0': '10', '长度1': '64', '长度2': '1', '长度3': '1', '长度4': '8', '长度5': '6', '长度6': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N'}, '备注': {'备注0': '理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '属性编码', '备注2': '与或关系类型:1-与 2-或', '备注3': '状态:1- 正常 2- 无效', '备注4': '最后修改日期', '备注5': '最后修改时间', '备注6': '最后操作员'}}}}
# {'gf_reservation_buy_info（理财产品预约购买属性信息）': {'说明': '该表存储设置预约购买属性的理财产品信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_RESERVATION_BUY_INFO主键字段：prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'order_begin_date', '列名2': 'order_end_date', '列名3': 'order_final_validity_date', '列名4': 'order_take_back_time', '列名5': 'latest_modify_date', '列名6': 'latest_modify_time', '列名7': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '预约起始日', '中文名称2': '预约终止日', '中文名称3': '预约最终有效日', '中文名称4': '预约额度回收时间', '中文名称5': '最后修改日期', '中文名称6': '最后修改时间', '中文名称7': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'varchar2', '类型6': 'varchar2', '类型7': 'varchar2'}, '长度': {'长度0': '10', '长度1': '8', '长度2': '8', '长度3': '8', '长度4': '30', '长度5': '8', '长度6': '6', '长度7': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'Y', '可空5': 'N', '可空6': 'N', '可空7': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '预约起始日', '备注2': '预约终止日', '备注3': '预约最终有效日', '备注4': '预约额度回收时间', '备注5': '最后修改日期', '备注6': '最后修改时间', '备注7': '最后操作员'}}}}
# {'gf_prod_buy_info（理财产品认购参数表）': {'说明': '？ 该表存储行内发行的理财产品的认购类属性信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_BUY_INFO主键字段：prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'raising_begin_date', '列名2': 'raising_begin_time', '列名3': 'raising_end_date', '列名4': 'raising_end_time', '列名5': 'charge_type', '列名6': 'quot_affirm_type', '列名7': 'plan_issue_amt', '列名8': 'already_buy_amt', '列名9': 'latest_modify_date', '列名10': 'latest_modify_time', '列名11': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '募集起始日期（从）', '中文名称2': '募集起始时间（从） ', '中文名称3': '募集结束日期（到）', '中文名称4': '募集结束时间（到）', '中文名称5': '扣款方式', '中文名称6': '份额确认方式', '中文名称7': '计划发售金额', '中文名称8': '已初始化认购金额', '中文名称9': '最后修改日期', '中文名称10': '最后修改时间', '中文名称11': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'char', '类型6': 'char', '类型7': 'number', '类型8': 'number', '类型9': 'varchar2', '类型10': 'varchar2', '类型11': 'varchar2'}, '长度': {'长度0': '10', '长度1': '8', '长度2': '6', '长度3': '8', '长度4': '6', '长度5': '1', '长度6': '1', '长度7': '22', '长度8': '22', '长度9': '8', '长度10': '6', '长度11': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'Y', '可空3': 'N', '可空4': 'Y', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N', '可空9': 'N', '可空10': 'N', '可空11': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '募集起始日期（从）', '备注2': '募集起始时间（从） ', '备注3': '募集结束日期（到）', '备注4': '募集结束时间（到）', '备注5': '扣款方式 1-批量扣款 2-实时扣款', '备注6': '份额确认方式: 1-批量确认 2-实时确认', '备注7': '计划发售金额', '备注8': '', '备注9': '最后修改日期', '备注10': '最后修改时间', '备注11': '最后操作员'}}}}
# {'gf_prod_open_duration_info（开放式理财产品存续期属性参数）': {'说明': '开放式产品存续期的一些属性，包括申购期的维护，赎回期的维护', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_OPEN_DURATION_INFO主键字段：end_date，begin_date，para_type，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'para_type', '列名2': 'begin_date', '列名3': 'end_date', '列名4': 'already_purchase_amt', '列名5': 'limit', '列名6': 'amt_handle_flag', '列名7': 'quot_affirm_type', '列名8': 'quot_affirm_date', '列名9': 'handle_flag', '列名10': 'valid_status', '列名11': 'latest_modify_date', '列名12': 'latest_modify_time', '列名13': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '参数类型', '中文名称2': '启用日期', '中文名称3': '终止日期', '中文名称4': '已初始化申购金额', '中文名称5': '开放期额度', '中文名称6': '资金处理方式', '中文名称7': '份额确认方式', '中文名称8': '份额确认日', '中文名称9': '处理标志', '中文名称10': '状态', '中文名称11': '最后修改日期', '中文名称12': '最后修改时间', '中文名称13': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'char', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'number', '类型5': 'number', '类型6': 'char', '类型7': 'char', '类型8': 'varchar2', '类型9': 'char', '类型10': 'char', '类型11': 'varchar2', '类型12': 'varchar2', '类型13': 'varchar2'}, '长度': {'长度0': '10', '长度1': '1', '长度2': '8', '长度3': '8', '长度4': '22', '长度5': '22', '长度6': '1', '长度7': '1', '长度8': '8', '长度9': '1', '长度10': '1', '长度11': '8', '长度12': '6', '长度13': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'Y', '可空6': 'N', '可空7': 'N', '可空8': 'Y', '可空9': 'Y', '可空10': 'N', '可空11': 'N', '可空12': 'N', '可空13': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品代码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '参数类型：1-申购，2-赎回', '备注2': '启用日期', '备注3': '终止日期', '备注4': '', '备注5': '开放期额度 特指当前申购期的开放总额度', '备注6': '申购扣款方式，赎回存款方式1-批量 2-实时', '备注7': '份额确认方式: 1-批量确认 2-实时确认', '备注8': '份额确认日', '备注9': '0-未处理 1-已处理', '备注10': '状态 1- 启用 2- 停用', '备注11': '最后修改日期', '备注12': '最后修改时间', '备注13': '最后操作员'}}}}
# {'gf_prod_redeem_info（理财产品赎回参数表）': {'说明': '该表存储行内发行的理财产品的赎回属性信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_REDEEM_INFO主键字段：prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'low_duration_days', '列名2': 'low_daily_redeem_quot', '列名3': 'high_daily_redeem_quot', '列名4': 'corp_low_duration_days', '列名5': 'corp_low_daily_redeem_quot', '列名6': 'corp_high_daily_redeem_quot', '列名7': 'max_redeem_per', '列名8': 'is_huge_redeem', '列名9': 'latest_modify_date', '列名10': 'latest_modify_time', '列名11': 'latest_oper_code', '列名12': 'holiday_redeem_limit'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '个人最小存续期', '中文名称2': '个人客户单日最低赎回份额', '中文名称3': '个人客户单日最大赎回份额', '中文名称4': '机构最小存续期', '中文名称5': '机构客户单日最低赎回份额', '中文名称6': '机构客户单日最大赎回份额', '中文名称7': '最大赎回比例', '中文名称8': '是否巨额赎回', '中文名称9': '最后修改日期', '中文名称10': '最后修改时间', '中文名称11': '最后操作员', '中文名称12': '产品节假日净赎回限额'}, '类型': {'类型0': 'varchar2', '类型1': 'number', '类型2': 'number', '类型3': 'number', '类型4': 'number', '类型5': 'number', '类型6': 'number', '类型7': 'number', '类型8': 'char', '类型9': 'varchar2', '类型10': 'varchar2', '类型11': 'varchar2', '类型12': 'number'}, '长度': {'长度0': '10', '长度1': '22', '长度2': '22', '长度3': '22', '长度4': '22', '长度5': '22', '长度6': '22', '长度7': '22', '长度8': '1', '长度9': '8', '长度10': '6', '长度11': '11', '长度12': '22'}, '可空': {'可空0': 'N', '可空1': 'Y', '可空2': 'Y', '可空3': 'Y', '可空4': 'Y', '可空5': 'Y', '可空6': 'Y', '可空7': 'Y', '可空8': 'N', '可空9': 'N', '可空10': 'N', '可空11': 'N', '可空12': 'Y'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品代码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '个人最小存续期', '备注2': '个人客户单日最低赎回份额', '备注3': '个人客户单日最大赎回份额', '备注4': '机构最小存续期', '备注5': '机构客户单日最低赎回份额', '备注6': '机构客户单日最大赎回份额', '备注7': '最大赎回比例:超过认为巨额 10% ', '备注8': '是否巨额赎回:0-否 1-是 ', '备注9': '最后修改日期', '备注10': '最后修改时间', '备注11': '最后操作员', '备注12': '产品节假日净赎回限额'}}}}
# {'gf_prod_dividend_info（理财产品分红参数信息）': {'说明': '记录理财产品分红参数', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_DIVIDEND_INFO主键字段：registration_date，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'registration_date', '列名2': 'dividend_per_unit', '列名3': 'dividend_status', '列名4': 'latest_modify_date', '列名5': 'latest_modify_time', '列名6': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '权益登记日', '中文名称2': '每份分红金额', '中文名称3': '状态', '中文名称4': '最后修改日期', '中文名称5': '最后修改时间', '中文名称6': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'number', '类型3': 'char', '类型4': 'varchar2', '类型5': 'varchar2', '类型6': 'varchar2'}, '长度': {'长度0': '10', '长度1': '8', '长度2': '22', '长度3': '1', '长度4': '8', '长度5': '6', '长度6': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '权益登记日', '备注2': '每份分红金额', '备注3': '状态 1- 未分红 2- 已分红', '备注4': '最后修改日期', '备注5': '最后修改时间', '备注6': '最后操作员'}}}}
# {'gf_prod_netvalue_info（理财产品净值信息表）': {'说明': '该表存储理财产品净值信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_NETVALUE_INFO主键字段：valid_status，net_value_date，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'net_value_date', '列名2': 'net_value', '列名3': 'profit_rate', '列名4': 'ten_thousandth_profit', '列名5': 'valid_status', '列名6': 'latest_modify_date', '列名7': 'latest_modify_time', '列名8': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '净值日期', '中文名称2': '净值', '中文名称3': '年化收益率', '中文名称4': '万份收益（元）', '中文名称5': '状态', '中文名称6': '最后修改日期', '中文名称7': '最后修改时间', '中文名称8': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'number', '类型3': 'number', '类型4': 'number', '类型5': 'char', '类型6': 'varchar2', '类型7': 'varchar2', '类型8': 'varchar2'}, '长度': {'长度0': '10', '长度1': '8', '长度2': '22', '长度3': '22', '长度4': '22', '长度5': '1', '长度6': '8', '长度7': '6', '长度8': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '净值日期', '备注2': '净值', '备注3': '年化收益率', '备注4': '万份收益（元）', '备注5': '状态1- 正常 2- 无效', '备注6': '最后修改日期', '备注7': '最后修改时间', '备注8': '最后操作员'}}}}
# {'gf_prod_fix_profit_rate（理财产品固定收益类信息）': {'说明': '该表存储对固定收益类产品收益率信息维护记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_FIX_PROFIT_RATE主键字段：cust_type，begin_date，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'profit_rate', '列名2': 'begin_date', '列名3': 'cust_type', '列名4': 'valid_status', '列名5': 'latest_modify_date', '列名6': 'latest_modify_time', '列名7': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '持有期间收益', '中文名称2': '启用日期', '中文名称3': '客户类型', '中文名称4': '状态', '中文名称5': '最后修改日期', '中文名称6': '最后修改时间', '中文名称7': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'number', '类型2': 'varchar2', '类型3': 'char', '类型4': 'char', '类型5': 'varchar2', '类型6': 'varchar2', '类型7': 'varchar2'}, '长度': {'长度0': '10', '长度1': '22', '长度2': '8', '长度3': '1', '长度4': '1', '长度5': '8', '长度6': '6', '长度7': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '持有期间收益(%)', '备注2': '启用日期', '备注3': '0-不区分 1-个人 2-公司', '备注4': '状态1- 正常 2- 无效', '备注5': '最后修改日期', '备注6': '最后修改时间', '备注7': '最后操作员'}}}}
# {'gf_prod_fix_period_profit_rate（理财产品固定期限收益组合类信息）': {'说明': '该表存储对固定收益类产品进行分档后维护的收益率信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_FIX_PERIOD_PROFIT_R主键字段：cust_type，duration_period，begin_date，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'duration_period', '列名2': 'profit_rate', '列名3': 'begin_date', '列名4': 'cust_type', '列名5': 'valid_status', '列名6': 'latest_modify_date', '列名7': 'latest_modify_time', '列名8': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '存续周期', '中文名称2': '持有期间收益', '中文名称3': '启用日期', '中文名称4': '客户类型', '中文名称5': '状态', '中文名称6': '最后修改日期', '中文名称7': '最后修改时间', '中文名称8': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'number', '类型2': 'number', '类型3': 'varchar2', '类型4': 'char', '类型5': 'char', '类型6': 'varchar2', '类型7': 'varchar2', '类型8': 'varchar2'}, '长度': {'长度0': '10', '长度1': '22', '长度2': '22', '长度3': '8', '长度4': '1', '长度5': '1', '长度6': '8', '长度7': '6', '长度8': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '0-基础收益率对应的存续周期(客户实际持有期小于选择存续期时使用)  非0代表其他档的存续期 ', '备注2': '持有期间收益(%)', '备注3': '启用日期', '备注4': '0-不区分 1-个人 2-公司', '备注5': '状态1- 正常 2- 无效', '备注6': '最后修改日期', '备注7': '最后修改时间', '备注8': '最后操作员'}}}}
# {'gf_prod_scale_profit_rate（理财产品规模收益计算类信息）': {'说明': '该表存储按规模分档类理财产品的收益率信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_PROD_SCALE_PROFIT_RATE主键字段：begin_date，high_amt，low_amt，cust_type，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'cust_type', '列名2': 'low_amt', '列名3': 'high_amt', '列名4': 'profit_rate', '列名5': 'begin_date', '列名6': 'valid_status', '列名7': 'latest_modify_date', '列名8': 'latest_modify_time', '列名9': 'latest_oper_code', '列名10': 'net_value'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '客户类型', '中文名称2': '金额下限（含）', '中文名称3': '金额上限', '中文名称4': '持有期间收益', '中文名称5': '启用日期', '中文名称6': '状态', '中文名称7': '最后修改日期', '中文名称8': '最后修改时间', '中文名称9': '最后操作员', '中文名称10': '净值'}, '类型': {'类型0': 'varchar2', '类型1': 'char', '类型2': 'number', '类型3': 'number', '类型4': 'number', '类型5': 'varchar2', '类型6': 'char', '类型7': 'varchar2', '类型8': 'varchar2', '类型9': 'varchar2', '类型10': 'number'}, '长度': {'长度0': '10', '长度1': '1', '长度2': '22', '长度3': '22', '长度4': '22', '长度5': '8', '长度6': '1', '长度7': '8', '长度8': '6', '长度9': '11', '长度10': '22'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N', '可空9': 'N', '可空10': 'Y'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '0-不区分 1-个人 2-公司', '备注2': '金额下限（含）', '备注3': '金额上限', '备注4': '持有期间收益(%)', '备注5': '启用日期', '备注6': '状态1- 正常 2- 无效', '备注7': '最后修改日期', '备注8': '最后修改时间', '备注9': '最后操作员', '备注10': '对应分档的收益率计算分档净值'}}}}
# {'gf_prod_fel_period_profit_rate（理财产品灵活期限收益组合类信息）': {'说明': '该表存储灵活期限类产品收益率信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_FEL_PERIOD_PROFIT_R主键字段：cust_type，period_high，organ_code，period_low，begin_date，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'organ_code', '列名2': 'period_low', '列名3': 'period_high', '列名4': 'profit_rate', '列名5': 'begin_date', '列名6': 'cust_type', '列名7': 'valid_status', '列名8': 'latest_modify_date', '列名9': 'latest_modify_time', '列名10': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '机构代码', '中文名称2': '期限下限', '中文名称3': '期限上限(含)', '中文名称4': '持有期间收益', '中文名称5': '启用日期', '中文名称6': '客户类型', '中文名称7': '状态', '中文名称8': '最后修改日期', '中文名称9': '最后修改时间', '中文名称10': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'number', '类型5': 'varchar2', '类型6': 'char', '类型7': 'char', '类型8': 'varchar2', '类型9': 'varchar2', '类型10': 'varchar2'}, '长度': {'长度0': '10', '长度1': '8', '长度2': '10', '长度3': '10', '长度4': '22', '长度5': '8', '长度6': '1', '长度7': '1', '长度8': '8', '长度9': '6', '长度10': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N', '可空9': 'N', '可空10': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '机构代码', '备注2': '期限下限', '备注3': '期限上限(含)', '备注4': '持有期间收益(%)', '备注5': '启用日期', '备注6': '0-不区分 1-个人 2-公司', '备注7': '状态 1- 正常 2- 无效', '备注8': '最后修改日期', '备注9': '最后修改时间', '备注10': '最后操作员'}}}}
# {'gf_prod_fix_sell_fee_rate（理财产品固定销售费率表）': {'说明': '该表存储理财产品销售费率信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_FIX_SELL_FEE_RATE主键字段：cust_type，begin_date，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'sell_rate', '列名2': 'begin_date', '列名3': 'cust_type', '列名4': 'valid_status', '列名5': 'latest_modify_date', '列名6': 'latest_modify_time', '列名7': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '销售费率', '中文名称2': '启用日期', '中文名称3': '客户类型', '中文名称4': '状态', '中文名称5': '最后修改日期', '中文名称6': '最后修改时间', '中文名称7': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'number', '类型2': 'varchar2', '类型3': 'char', '类型4': 'char', '类型5': 'varchar2', '类型6': 'varchar2', '类型7': 'varchar2'}, '长度': {'长度0': '10', '长度1': '22', '长度2': '8', '长度3': '1', '长度4': '1', '长度5': '8', '长度6': '6', '长度7': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '销售费率', '备注2': '启用日期', '备注3': '0-不区分 1-个人 2-公司', '备注4': '状态 1- 正常 2- 无效', '备注5': '最后修改日期', '备注6': '最后修改时间', '备注7': '最后操作员'}}}}
# {'gf_prod_fel_sell_fee_rate（理财产品灵活销售费率表）': {'说明': '该表存储理财产品销售费率信息记录', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_FEL_SELL_FEE_RATE主键字段：cust_type，begin_date，period_high，period_low，organ_code，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'organ_code', '列名2': 'period_low', '列名3': 'period_high', '列名4': 'sell_rate', '列名5': 'begin_date', '列名6': 'cust_type', '列名7': 'valid_status', '列名8': 'latest_modify_date', '列名9': 'latest_modify_time', '列名10': 'latest_oper_code'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '机构代码', '中文名称2': '期限下限', '中文名称3': '期限上限(含)', '中文名称4': '销售费率', '中文名称5': '启用日期', '中文名称6': '客户类型', '中文名称7': '状态', '中文名称8': '最后修改日期', '中文名称9': '最后修改时间', '中文名称10': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'number', '类型5': 'varchar2', '类型6': 'char', '类型7': 'char', '类型8': 'varchar2', '类型9': 'varchar2', '类型10': 'varchar2'}, '长度': {'长度0': '10', '长度1': '8', '长度2': '10', '长度3': '10', '长度4': '22', '长度5': '8', '长度6': '1', '长度7': '1', '长度8': '8', '长度9': '6', '长度10': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N', '可空9': 'N', '可空10': 'N'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '机构代码', '备注2': '期限下限', '备注3': '期限上限(含)', '备注4': '销售费率', '备注5': '启用日期', '备注6': '0-不区分 1-个人 2-公司', '备注7': '状态 1- 正常 2- 无效', '备注8': '最后修改日期', '备注9': '最后修改时间', '备注10': '最后操作员'}}}}
# {'gf_prod_statistics_para（产品统计口径参数表）': {'说明': '该表登记产品统计口径参数', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：16384  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_STATISTICS_PARA主键字段：statistics_flag，statistics_type，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'statistics_type', '列名2': 'trust_capital_invest', '列名3': 'subject_matter', '列名4': 'overseas_capital_operation', '列名5': 'invest_type', '列名6': 'prod_trust_business_type', '列名7': 'statistics_flag', '列名8': 'statistics_duty_cycle', '列名9': 'profit_type'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '统计类型', '中文名称2': '按信托资金投向划分', '中文名称3': '按挂钩标的划分', '中文名称4': '按境外资金运作方式划分', '中文名称5': '理财投资', '中文名称6': '理财产品按托管业务划分', '中文名称7': '统计口径标志', '中文名称8': '统计占比', '中文名称9': '产品收益类型'}, '类型': {'类型0': 'varchar2', '类型1': 'char', '类型2': 'char', '类型3': 'char', '类型4': 'char', '类型5': 'char', '类型6': 'char', '类型7': 'varchar2', '类型8': 'number', '类型9': 'char'}, '长度': {'长度0': '10', '长度1': '1', '长度2': '1', '长度3': '1', '长度4': '1', '长度5': '1', '长度6': '1', '长度7': '2', '长度8': '22', '长度9': '2'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'Y', '可空3': 'Y', '可空4': 'Y', '可空5': 'Y', '可空6': 'Y', '可空7': 'N', '可空8': 'N', '可空9': 'Y'}, '备注': {'备注0': '通过视图查询品牌信息，理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '0-债券及货币市场工具类 1-信托类  2-结构性理财  3- 代客境外理财产品  4-其他理财产品 5-按人行统计划分 6-G06理财业务统计', '备注2': '按信托资金投向划分:0-信贷资产类 1-资本市场类 2-其他类', '备注3': '按挂钩标的划分:0-挂钩汇率类 1-挂钩利率类 2-挂钩信用类 3-挂钩股票类 4-挂钩商品类 5-挂钩基金类 6-其他类', '备注4': '按境外资金运作方式划分:0-债券、货币市场工具及货币市场基金 1-股票及股票型基金 2-结构性票据 3-其他类', '备注5': '理财投资（人行统计）:0-黄金 1-现金 2-银行存款 3-贷款 4-非股票证券 5-股票及其他股权 6-金融衍生产品 7-其他', '备注6': '理财产品按托管业务划分：0-银行理财产品 1-信托产品 2-银行理财产品2', '备注7': '统计口径标志 0-个人理财产品 1-私人银行专属理财产品 2-机构专属理财产品 6-T+0产品 7-7天(含)以内产品 8-7天至1个月(含) 9-1个月到3个月(含) 10-3个月到6个月(含) 11-6个月到12个月(含) 12-1年以上 13-人民币 14-外币(全折人民币） 15-未投资头寸 16-国债、央票、政策性金融债 17-AA+(含)以上信用债券 18-AA+以下信用债券 19-正回购 20-逆回购 21-拆入 22-拆出 23-其他债券及货币市场工具 24-本行存款 25-他行存款 26-其他存款 27-债权类 28-银行承兑汇票 29-商业承兑汇票 30-其他票据 31-其他信贷类投资\t 32-结构股权投资 33-PE投资 34-资本市场 35-其他权益类投资 36-衍生工具 37-QDII 38-另类投资 39-其他', '备注8': '统计占比', '备注9': '产品收益类型: 01 保证收益, 02 保本浮动收益, 03 非保本浮动收益 '}}}}
# {'gf_prod_profit_detail（开放式收益率产品每日收益明细表）': {'说明': '该表登记开放式收益率产品每日收益明细表', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_PROFIT_DETAIL主键字段：prod_code，trade_date，cust_type，application_code', '索引': '', '字段': {'列名': {'列名0': 'trade_date', '列名1': 'ta_code', '列名2': 'application_code', '列名3': 'prod_code', '列名4': 'daily_quot', '列名5': 'daily_profit', '列名6': 'sum_profit', '列名7': 'cust_type', '列名8': 'hold_days'}, '中文名称': {'中文名称0': '交易日期', '中文名称1': 'TA账号', '中文名称2': '申请单编号', '中文名称3': '理财产品编码', '中文名称4': '当日保有量', '中文名称5': '当日收益', '中文名称6': '累计收益', '中文名称7': '客户类型', '中文名称8': '持有天数'}, '类型': {'类型0': 'date', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'number', '类型5': 'number', '类型6': 'number', '类型7': 'char', '类型8': 'number'}, '长度': {'长度0': '7', '长度1': '15', '长度2': '20', '长度3': '10', '长度4': '22', '长度5': '22', '长度6': '22', '长度7': '1', '长度8': '22'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N'}, '备注': {'备注0': '交易日期', '备注1': 'TA账号', '备注2': '申请单编号', '备注3': '理财产品编码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注4': '当日保有量', '备注5': '当日收益', '备注6': '累计收益', '备注7': '0-不区分 1-个人 2-公司', '备注8': '持有天数'}}}}
# {'gf_prod_redeem_detail（理财产品赎回明细表）': {'说明': '理财产品赎回明细表', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_PROD_REDEEM_DETAIL主键字段：end_date，begin_date，cust_type，organ_code，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'organ_code', '列名2': 'cust_type', '列名3': 'begin_date', '列名4': 'end_date', '列名5': 'application_code', '列名6': 'limit_deduction_flag', '列名7': 'limit', '列名8': 'cancel_flag', '列名9': 'handle_flag', '列名10': 'last_handle_date'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '机构代码', '中文名称2': '客户类型', '中文名称3': '开始日期', '中文名称4': '结束日期', '中文名称5': '申请单编号', '中文名称6': '额度扣减标志', '中文名称7': '额度', '中文名称8': '撤单标志', '中文名称9': '处理标志', '中文名称10': '最后处理时间'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'char', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'varchar2', '类型6': 'char', '类型7': 'number', '类型8': 'char', '类型9': 'char', '类型10': 'varchar2'}, '长度': {'长度0': '10', '长度1': '8', '长度2': '1', '长度3': '8', '长度4': '8', '长度5': '20', '长度6': '1', '长度7': '22', '长度8': '1', '长度9': '1', '长度10': '8'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'N', '可空9': 'Y', '可空10': 'N'}, '备注': {'备注0': '理财产品代码规则（位数）：发行年度（2）＋币种（2）＋产品品牌代码（2）+产品期次序数（4）', '备注1': '机构代码', '备注2': '客户类型:1-个人 2-公司', '备注3': '开始日期', '备注4': '结束日期', '备注5': '申请单编号', '备注6': '额度扣减标志 1-预约,2-认购,3-申购', '备注7': '额度', '备注8': '撤单标志 0-正常 1-撤销', '备注9': '处理标志 0-未处理 1-已处理', '备注10': '最后处理时间'}}}}
# ...
# {'gf_recom_detail_info（推荐费明细信息表）': {'说明': '记录与资管系统同步过来的推荐费明细', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：0  下次分配大小：0  最小分配：0  最大分配：0', '主键': '主键名称：PK_GF_RECOM_DETAIL_INFO主键字段：chl_no，begin_date，prod_code，syn_type', '索引': '', '字段': {'列名': {'列名0': 'notify_code', '列名1': 'inotify_content', '列名2': 'latest_modify_date', '列名3': 'latest_modify_time', '列名4': 'latest_oper_code'}, '中文名称': {'中文名称0': '通知代码', '中文名称1': '通知内容', '中文名称2': '最后修改日期', '中文名称3': '最后修改时间', '中文名称4': '最后操作员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2'}, '长度': {'长度0': '40', '长度1': '4000', '长度2': '8', '长度3': '6', '长度4': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N'}, '备注': {'备注0': '通知代码', '备注1': '通知内容', '备注2': '最后修改日期', '备注3': '最后修改时间', '备注4': '最后操作员'}}}}
# {'gf_fee_sum_info（手续费分配汇总信息表）': {'说明': '记录与资管系统同步过来的推荐费、销售费月汇总数据。', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_FEE_SUM_INFO主键字段：begin_date，fee_type，prod_code', '索引': '', '字段': {'列名': {'列名0': 'organ_code', '列名1': 'trade_date', '列名2': 'prod_code', '列名3': 'cust_flag', '列名4': 'poss_quot_daily', '列名5': 'charge_daily', '列名6': 'handle_flag'}, '中文名称': {'中文名称0': '机构代码', '中文名称1': '交易日期', '中文名称2': '理财产品编码', '中文名称3': '客户标识', '中文名称4': '当日持有份额', '中文名称5': '当日手续费', '中文名称6': '处理标志'}, '类型': {'类型0': 'varchar2', '类型1': 'date', '类型2': 'varchar2', '类型3': 'char', '类型4': 'number', '类型5': 'number', '类型6': 'char'}, '长度': {'长度0': '8', '长度1': '7', '长度2': '10', '长度3': '1', '长度4': '22', '长度5': '22', '长度6': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'Y', '可空5': 'Y', '可空6': 'N'}, '备注': {'备注0': '机构代码', '备注1': '交易日期', '备注2': '通过视图查询品牌信息，理财产品代码规则（位数）：发行年度（2）＋自营/代销（1）+机构代码（1）＋币种（1）＋期限（2位，以月为单位）＋产品品牌代码（1）+产品期次序数（2）', '备注3': '1个人  2机构  3同业 4小企业', '备注4': '当日持有份额', '备注5': '当日手续费', '备注6': '0-未处理 1-已处理'}}}}
# {'gf_oper_profit_info（产品运作收益信息表）': {'说明': '记录开放式理财产品每日运作收益信息。', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_OPER_PROFIT_INFO主键字段：oper_date，prod_code', '索引': '', '字段': {'列名': {'列名0': 'organ_code', '列名1': 'trade_date', '列名2': 'prod_code', '列名3': 'cust_flag', '列名4': 'poss_quot_daily', '列名5': 'charge_daily', '列名6': 'handle_flag'}, '中文名称': {'中文名称0': '机构代码', '中文名称1': '交易日期', '中文名称2': '理财产品编码', '中文名称3': '客户标识', '中文名称4': '当日持有份额', '中文名称5': '当日手续费', '中文名称6': '处理标志'}, '类型': {'类型0': 'varchar2', '类型1': 'date', '类型2': 'varchar2', '类型3': 'char', '类型4': 'number', '类型5': 'number', '类型6': 'char'}, '长度': {'长度0': '8', '长度1': '7', '长度2': '10', '长度3': '1', '长度4': '22', '长度5': '22', '长度6': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'Y', '可空5': 'Y', '可空6': 'N'}, '备注': {'备注0': '机构代码', '备注1': '交易日期', '备注2': '通过视图查询品牌信息,理财产品代码规则(位数):发行年度(2)+币种(2)+产品品牌代码(2)+产品期次序数(4)', '备注3': '1个人  2机构  3同业 4小企业', '备注4': '当日持有份额', '备注5': '当日手续费', '备注6': '0-未处理 1-已处理'}}}}
# {'gf_pub_acct_std_info（产品账户信息表）': {'说明': '记录保本、非保本理财产品资金清算所使用的各类内部户', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：GF_PUB_ACCT_STD_INFO主键字段：break_even_type，acct_type', '索引': '', '字段': {'列名': {'列名0': 'organ_code', '列名1': 'trade_date', '列名2': 'prod_code', '列名3': 'cust_type', '列名4': 'poss_quot_daily', '列名5': 'charge_daily', '列名6': 'handle_flag'}, '中文名称': {'中文名称0': '机构代码', '中文名称1': '交易日期', '中文名称2': '理财产品编码', '中文名称3': '客户类型', '中文名称4': '当日持有份额', '中文名称5': '当日手续费', '中文名称6': '处理标志'}, '类型': {'类型0': 'varchar2', '类型1': 'date', '类型2': 'varchar2', '类型3': 'char', '类型4': 'number', '类型5': 'number', '类型6': 'char'}, '长度': {'长度0': '8', '长度1': '7', '长度2': '10', '长度3': '1', '长度4': '22', '长度5': '22', '长度6': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'Y', '可空5': 'Y', '可空6': 'Y'}, '备注': {'备注0': '机构代码', '备注1': '计提日期', '备注2': '通过视图查询品牌信息,理财产品代码规则(位数):发行年度(2)+币种(2)+产品品牌代码(2)+产品期次序数(4)', '备注3': '0-不区分 1-个人 2-公司', '备注4': '当日持有份额', '备注5': '当日手续费', '备注6': '0-未处理 1-已处理'}}}}
# {'gf_send_data_info（资管系统同步数据发送结果信息表）': {'说明': '记录与资管系统同步数据发送结果', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：16384  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_SEND_DATA_INFO主键字段：trade_time，trade_date，send_type，prod_code，syn_type', '索引': '', '字段': {'列名': {'列名0': 'trade_organ', '列名1': 'trade_date', '列名2': 'prod_code', '列名3': 'cust_type', '列名4': 'poss_quot_daily', '列名5': 'charge_daily', '列名6': 'handle_flag'}, '中文名称': {'中文名称0': '交易机构', '中文名称1': '交易日期', '中文名称2': '理财产品编码', '中文名称3': '客户类型', '中文名称4': '当日持有份额', '中文名称5': '当日手续费', '中文名称6': '处理标志'}, '类型': {'类型0': 'varchar2', '类型1': 'date', '类型2': 'varchar2', '类型3': 'char', '类型4': 'number', '类型5': 'number', '类型6': 'char'}, '长度': {'长度0': '8', '长度1': '7', '长度2': '10', '长度3': '1', '长度4': '22', '长度5': '22', '长度6': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'Y', '可空5': 'Y', '可空6': 'Y'}, '备注': {'备注0': '交易机构', '备注1': '交易日期', '备注2': '通过视图查询品牌信息,理财产品代码规则(位数):发行年度(2)+币种(2)+产品品牌代码(2)+产品期次序数(4)', '备注3': '0-不区分 1-个人 2-公司', '备注4': '当日持有份额', '备注5': '当日手续费', '备注6': '0-未处理 1-已处理'}}}}
# {'gf_recv_capital_data_info（同步资金到账接收记录表）': {'说明': '记录同步资金到账接收记录表', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_GF_RECV_CAPITAL_DATA_INFO主键字段：prod_code，capital_type，batch_date', '索引': '', '字段': {'列名': {'列名0': 'retailer_code', '列名1': 'prod_code', '列名2': 'buy_quot', '列名3': 'purchase_quot', '列名4': 'redeem_quot', '列名5': 'only_redeem_quot', '列名6': 'can_affrim_quot', '列名7': 'register_date'}, '中文名称': {'中文名称0': '销售商代码', '中文名称1': '理财产品编码', '中文名称2': '认购份额', '中文名称3': '申购份额', '中文名称4': '赎回份额', '中文名称5': '净赎回份额', '中文名称6': '可确认总份额', '中文名称7': '登记日期'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'number', '类型3': 'number', '类型4': 'number', '类型5': 'number', '类型6': 'number', '类型7': 'varchar2'}, '长度': {'长度0': '10', '长度1': '10', '长度2': '22', '长度3': '22', '长度4': '22', '长度5': '22', '长度6': '22', '长度7': '8'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'Y', '可空5': 'Y', '可空6': 'Y', '可空7': 'N'}, '备注': {'备注0': '销售商代码', '备注1': '理财产品代码规则(位数):发行年度(2)+币种(2)+产品品牌代码(2)+产品期次序数(4)', '备注2': '认购份额', '备注3': '申购份额', '备注4': '赎回份额', '备注5': '净赎回份额', '备注6': '可确认总份额', '备注7': '登记日期'}}}}
# {'gf_fee_sum_info（手续费分配汇总信息表）': {'说明': '记录与资管系统同步过来的推荐费、销售费月汇总数据。', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_FEE_SUM_INFO主键字段：begin_date，fee_type，prod_code', '索引': '', '字段': {'列名': {'列名0': 'suiet_code', '列名1': 'suiet_name', '列名2': 'task_code', '列名3': 'task_name', '列名4': 'task_para', '列名5': 'run_cmd', '列名6': 'run_status', '列名7': 'run_date', '列名8': 'task_desc', '列名9': 'log_file', '列名10': 'update_time', '列名11': 'update_oper', '列名12': 'create_time', '列名13': 'create_oper'}, '中文名称': {'中文名称0': '分组号', '中文名称1': '分组名', '中文名称2': '任务号', '中文名称3': '任务名', '中文名称4': '任务参数', '中文名称5': '执行命令', '中文名称6': '执行结果', '中文名称7': '任务执行日期', '中文名称8': '任务描述', '中文名称9': '日志文件', '中文名称10': '更新时间', '中文名称11': '更新人员', '中文名称12': '创建时间', '中文名称13': '创建人员'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'varchar2', '类型6': 'char', '类型7': 'varchar2', '类型8': 'varchar2', '类型9': 'varchar2', '类型10': 'varchar2', '类型11': 'varchar2', '类型12': 'varchar2', '类型13': 'varchar2'}, '长度': {'长度0': '64', '长度1': '128', '长度2': '64', '长度3': '128', '长度4': '128', '长度5': '128', '长度6': '1', '长度7': '8', '长度8': '1024', '长度9': '256', '长度10': '6', '长度11': '11', '长度12': '6', '长度13': '11'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'Y', '可空5': 'N', '可空6': 'N', '可空7': 'N', '可空8': 'Y', '可空9': 'Y', '可空10': 'Y', '可空11': 'Y', '可空12': 'N', '可空13': 'N'}, '备注': {'备注0': '分组号', '备注1': '分组名', '备注2': '任务号', '备注3': '任务名', '备注4': '任务参数', '备注5': '执行命令', '备注6': '0-未执行 1-已执行成功 2-已执行失败', '备注7': '任务执行日期', '备注8': '任务描述', '备注9': '日志文件', '备注10': '更新时间', '备注11': '更新人员', '备注12': '创建时间', '备注13': '创建人员'}}}}
# {'gf_oper_profit_info（产品运作收益信息表）': {'说明': '记录开放式理财产品每日运作收益信息。', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：1048576  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_OPER_PROFIT_INFO主键字段：oper_date，prod_code', '索引': '', '字段': {'列名': {'列名0': 'task_code', '列名1': 'batch_serial', '列名2': 'run_cmd', '列名3': 'begin_date', '列名4': 'end_date', '列名5': 'task_status', '列名6': 'cust_type'}, '中文名称': {'中文名称0': '任务号', '中文名称1': '批次号', '中文名称2': '执行命令', '中文名称3': '开始时间', '中文名称4': '结束时间', '中文名称5': '任务状态', '中文名称6': '客户类型'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'char', '类型6': 'char'}, '长度': {'长度0': '14', '长度1': '20', '长度2': '128', '长度3': '8', '长度4': '8', '长度5': '1', '长度6': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'Y', '可空5': 'N', '可空6': 'N'}, '备注': {'备注0': '任务号', '备注1': '批次号', '备注2': '执行命令', '备注3': '开始时间', '备注4': '结束时间', '备注5': '1- 待核心系统返回 2- 任务执行中 3- 任务执行失败 4- 任务执行成功 ', '备注6': '客户类型:1-个人 2-公司:1-个人 2-公司'}}}}
# {'ta_sk_notify_info（收款通知单信息表）': {'说明': '记录理财产品赎回、分红、到期收款信息。给客户存款', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_TA_SK_NOTIFY_INFO主键字段：trade_kind_code，cust_type，prod_code，trade_date', '索引': '', '字段': {'列名': {'列名0': 'syn_type', '列名1': 'prod_code', '列名2': 'begin_date', '列名3': 'end_date', '列名4': 'amt', '列名5': 'chl_no', '列名6': 'distribute_flag'}, '中文名称': {'中文名称0': '机构代码', '中文名称1': '理财产品编码', '中文名称2': '开始日期', '中文名称3': '结束日期', '中文名称4': '金额', '中文名称5': '推荐渠道标识', '中文名称6': '分配标志'}, '类型': {'类型0': 'varchar2', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'number', '类型5': 'char', '类型6': 'char'}, '长度': {'长度0': '8', '长度1': '10', '长度2': '8', '长度3': '8', '长度4': '22', '长度5': '1', '长度6': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N'}, '备注': {'备注0': '机构代码', '备注1': '理财产品代码规则(位数):发行年度(2)+币种(2)+产品品牌代码(2)+产品期次序数(4)', '备注2': '开始日期', '备注3': '结束日期', '备注4': '金额', '备注5': '推荐渠道标识', '备注6': '分配标志:0-未分配 1-已分配'}}}}
# {'ta_hk_notify_info（划款通知单信息表）': {'说明': '记录理财产品赎回、分红、到期划款信息。收客户购买款', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_TA_HK_NOTIFY_INFO主键字段：trade_kind_code，cust_type，prod_code，trade_date', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'fee_type', '列名2': 'begin_date', '列名3': 'trade_date', '列名4': 'amt', '列名5': 'chl_no', '列名6': 'distribute_flag'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '手续费类型', '中文名称2': '开始日期', '中文名称3': '结束日期', '中文名称4': '金额', '中文名称5': '渠道标识', '中文名称6': '分配标志'}, '类型': {'类型0': 'varchar2', '类型1': 'char', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'number', '类型5': 'char', '类型6': 'char'}, '长度': {'长度0': '10', '长度1': '1', '长度2': '8', '长度3': '8', '长度4': '22', '长度5': '1', '长度6': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N'}, '备注': {'备注0': '理财产品代码规则(位数):发行年度(2)+币种(2)+产品品牌代码(2)+产品期次序数(4)', '备注1': '手续费类型:1-销售费 2-推荐费', '备注2': '计提开始日期', '备注3': '计提结束日期', '备注4': '金额', '备注5': '0[零] 公司贷款理财推荐费 A 小企业贷款 B 同业融资 C 债券 D 票据 E 其他', '备注6': '分配标志:0-未分配 1-已分配'}}}}
# {'gf_prod_acct_info（产品账户信息表）': {'说明': '记录保本、非保本理财产品资金清算所使用的各类内部户', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_PROD_ACCT_INFO主键字段：acct_type，prod_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'amt', '列名2': 'cost', '列名3': 'oper_date', '列名4': 'oper_profit'}, '中文名称': {'中文名称0': '理财产品编码', '中文名称1': '金额', '中文名称2': '成本', '中文名称3': '运作日期', '中文名称4': '运作收益'}, '类型': {'类型0': 'varchar2', '类型1': 'number', '类型2': 'number', '类型3': 'varchar2', '类型4': 'number'}, '长度': {'长度0': '10', '长度1': '22', '长度2': '22', '长度3': '8', '长度4': '22'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N'}, '备注': {'备注0': '理财产品代码规则(位数):发行年度(2)+币种(2)+产品品牌代码(2)+产品期次序数(4)', '备注1': '余额(亿元)', '备注2': '成本', '备注3': '运作日期', '备注4': '运作收益'}}}}
# {'ta_in_out_acct_ref（交易账户关系图）': {'说明': '存储理财资金交易中各交易账户之间关系信息', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：2147483645', '主键': '主键名称：PK_TA_IN_OUT_ACCT_REF主键字段：cust_type，profit_type，out_acct_type，trade_kind_code', '索引': '', '字段': {'列名': {'列名0': 'acct_type', '列名1': 'in_acct_code', '列名2': 'in_acct_name', '列名3': 'bank_item_code', '列名4': 'bank_item_name', '列名5': 'currency', '列名6': 'break_even_type'}, '中文名称': {'中文名称0': '账户类型', '中文名称1': '内部户帐号', '中文名称2': '内部账户名称', '中文名称3': '明细科目编号', '中文名称4': '明细科目名称', '中文名称5': '币种', '中文名称6': '产品保本类型'}, '类型': {'类型0': 'char', '类型1': 'varchar2', '类型2': 'varchar2', '类型3': 'varchar2', '类型4': 'varchar2', '类型5': 'varchar2', '类型6': 'char'}, '长度': {'长度0': '2', '长度1': '30', '长度2': '100', '长度3': '60', '长度4': '60', '长度5': '3', '长度6': '1'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'N', '可空6': 'N'}, '备注': {'备注0': '账户类型', '备注1': '内部户帐号', '备注2': '内部账户名称', '备注3': '明细科目编号', '备注4': '明细科目名称', '备注5': '币种', '备注6': '产品保本类型 0-保本 1-不保本'}}}}
# {'gf_hb_notify_app（资金划拨审批信息表）': {'说明': '存储资金划款审批流程与划款单之间的对应关系信息', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_HB_NOTIFY_APP主键字段：batch_serial，workflow_code', '索引': '', '字段': {'列名': {'列名0': 'syn_type', '列名1': 'prod_code', '列名2': 'send_type', '列名3': 'trade_date', '列名4': 'syn_status', '列名5': 'file_name', '列名6': 'return_code', '列名7': 'return_info', '列名8': 'trade_time'}, '中文名称': {'中文名称0': '同步类型', '中文名称1': '理财产品编码', '中文名称2': '发送方式', '中文名称3': '交易日期', '中文名称4': '同步状态', '中文名称5': '文件名称', '中文名称6': '返回码', '中文名称7': '返回信息', '中文名称8': '交易时间'}, '类型': {'类型0': 'char', '类型1': 'varchar2', '类型2': 'char', '类型3': 'date', '类型4': 'char', '类型5': 'varchar2', '类型6': 'varchar2', '类型7': 'varchar2', '类型8': 'varchar2'}, '长度': {'长度0': '2', '长度1': '10', '长度2': '1', '长度3': '7', '长度4': '1', '长度5': '200', '长度6': '6', '长度7': '200', '长度8': '6'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'Y', '可空6': 'Y', '可空7': 'Y', '可空8': 'N'}, '备注': {'备注0': '0-产品申报登记 1-理财产品基本信息 2-分档收益率参数 3-封闭式产品成立 4-封闭式产品分红 5-封闭式产品到期 6-开放式产品成立 7-开放式产品申购 8-开放式产品赎回 9-开放式产品到期 10-非保本产品负收益到账 11-开放式产品分红 12-开放式产品运作成本 13-理财产品投资者募集 14-理财产品销售费率参数', '备注1': '理财产品代码规则(位数):发行年度(2)+币种(2)+产品品牌代码(2)+产品期次序数(4)', '备注2': '1-单笔 2-批量', '备注3': '交易日期', '备注4': '1-待生成文件 2-文件已生成 3-文件发送失败 4-文件发送成功', '备注5': '文件名称', '备注6': '返回码000000-成功', '备注7': '返回信息', '备注8': '交易时间'}}}}
# {'gf_hb_notify_app（资金划拨审批信息表）': {'说明': '存储资金划款审批流程与划款单之间的对应关系信息', '表空间': '所在空表间：FUNDSYS_DATA_DBSPCT_FREE：10  初始交易：1  最大交易：255初始分配大小：65536  下次分配大小：8192  最小分配：1  最大分配：0', '主键': '主键名称：PK_GF_HB_NOTIFY_APP主键字段：batch_serial，workflow_code', '索引': '', '字段': {'列名': {'列名0': 'prod_code', '列名1': 'capital_type', '列名2': 'acc_flag', '列名3': 'amt', '列名4': 'batch_date', '列名5': 'acc_date'}, '中文名称': {'中文名称0': '理财产品代码', '中文名称1': '资金类型', '中文名称2': '到账标识', '中文名称3': '金额', '中文名称4': '批处理日期', '中文名称5': '到账日期'}, '类型': {'类型0': 'varchar2', '类型1': 'char', '类型2': 'char', '类型3': 'number', '类型4': 'varchar2', '类型5': 'varchar2'}, '长度': {'长度0': '10', '长度1': '1', '长度2': '1', '长度3': '22', '长度4': '8', '长度5': '8'}, '可空': {'可空0': 'N', '可空1': 'N', '可空2': 'N', '可空3': 'N', '可空4': 'N', '可空5': 'Y'}, '备注': {'备注0': '理财产品代码规则(位数):发行年度(2)+币种(2)+产品品牌代码(2)+产品期次序数(4)', '备注1': '1-赎回本金2-赎回收益3-分红利息3-到期本金4-赎回收益5-到期收益', '备注2': '0-未到账，1-已到账', '备注3': '金额', '备注4': '处理日期', '备注5': '到账日期'}}}}
