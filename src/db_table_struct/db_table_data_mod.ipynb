# %%
from docx import Document

def table(num,document):

    row1_list = []
    row_content = []
    """获取第一个表格内容"""
    table = document.tables[num]
    """获取第一行标题"""
    row_1 = table.row_cells(0)
    """将第一行标题提取出来"""
    for row in table.rows:
        for cell1 in row.cells:
    #            print(cell.text)
            for cell2 in row_1:
#                print(cell2.text)
                if cell1.text == cell2.text:
                    key = cell1.text                 
                    row1_list.append(key)
#                    print(key)
                    break
            else:
                """将内容提取出来"""
                value = cell1.text
                new_value = value.replace('\n', ' ')
                row_content.append(new_value)

    dict1={}

    for i in range(len(row1_list)): # 循环标题列表
        dict2={}
        a_list=[j for j in range(i,len(row_content),len(row1_list)) ] # 循环内容列表
        for k in range(len(a_list)):  
            dict2[row1_list[i]+str(k)] = row_content[a_list[k]] # 构造内层字典
        dict1[row1_list[i]] = dict2     # 构造整体字典
              
#    print(dict1)
    return dict1

# %%
def head3_index_get(paras,max_i,min_i):
    head3_index_list=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Heading 3':
            head3_index_list.append(i)
    return head3_index_list

def head4_index_get(paras,max_i,min_i):
    head4_index_list=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Heading 4':
            head4_index_list.append(i)
    return head4_index_list

def print_con(paras,index):
    for i in index:
        print("    " + paras[i].text)
        
def normal_get(paras,max_i,min_i):
    list_normat=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Normal':
            list_normat.append(paras[i].text)
    return list_normat

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jan 12 09:55:52 2018

@author: user
"""

from docx import Document
import json
def main(doc='./project_data/doc/理财监管新规数据库优化11.9.docx'):
    document = Document(doc)
    paras = document.paragraphs
    lcount = []  # 存储所有段落的对象 
    tables=0
    head2_dict={}
    head3_dict={}
    
  
    for i in range(len(paras)):
        if paras[i].style.name == 'Heading 2':
            lcount.append(i)
#            print(paras[i].text)
#    print(len(lcount))      
    # 提取每一段的数据
    for i in range(len(lcount)):
        if i+1 >= len(lcount):
            break
        ax = lcount[i]
        bx = lcount[i+1]
        head3_index_list=head3_index_get(paras,bx,ax)
        print(paras[ax].text)
        #print_con(paras,head3_index_list)
        for j in range(len(head3_index_list)):
            if j+1 >= len(head3_index_list):
                break
            head3_min = head3_index_list[j]
            head3_max = head3_index_list[j+1]
            head4_index_list=head4_index_get(paras,head3_max,head3_min)
            head4_dict={}
            #print(paras[head3_min].text)
            #print_con(paras,head4_index_list)
            for z in range(len(head4_index_list)):
                if z+1 >= len(head4_index_list):
                    break
                head4_min = head4_index_list[z]
                head4_max = head4_index_list[z+1]
                print(paras[head4_max].text)
                if '字段' in str(paras[head4_max].text) :
                    #for k in range(head4_min,head4_max):
                     #   print(paras[k].text)
                    table_dict=table(tables,document)
                    tables+=1
                    head4_dict[paras[head4_max].text]=table_dict
                else:
                    normal=normal_get(paras,head4_max,head4_min)
                    head4_dict[paras[head4_min].text]=''.join(normal).replace('\u3000', ' ')
            head3_dict[paras[head3_min].text]=head4_dict
            
            table_name=paras[head3_min].text.split('（')[0]
            file_name='./project_data/tables_json/'+table_name+'.json'
            print(file_name)
            with open(file_name,'w+') as f:
                str_data = json.dumps(head3_dict)
                f.write(str_data)

# %%
main('./project_data/doc/理财监管新规数据库优化11.9.docx')
# Out:
# 底层资产
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_asset_info.json
# 项目
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_asset_mutual_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prj_info.json
# 理财产品
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_register_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_brand_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_issue_area.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_retailer_limit_ctl.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_limit_ctl.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_base_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_organ_white_list.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_cust_white_list.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_point_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_pos_parameters.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_cust_prop.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_reservation_buy_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_buy_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_open_duration_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_redeem_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_dividend_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_netvalue_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_fix_profit_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_fix_period_profit_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_scale_profit_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_fel_period_profit_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_fix_sell_fee_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_fel_sell_fee_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_statistics_para.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_profit_detail.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_redeem_detail.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_LIMIT_detail.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_open_duration_rule.json
# 销售商
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_retailer_daily_redeem_info.json
# 销售渠道
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_channel.json
# 产品账户
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_trusteeship_acct.json
# 理财交易(销售系统)
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_auto_ctl_time_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_auto_open_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_timing_buy_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_order_auto_buy_agree.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_order_redeem_agree.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_order_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_cust_unconfirm_buy_amt.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_huge_redeem_vastly_ctl.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_pos_accin_list.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_pos_balance.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_quot_pledge_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_asset_prove_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_endday_trade_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_freeze_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_no_trade_transfer_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_sell_trade_list_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_cancell_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_checklist_point.json
# 理财账户
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_cust_acct_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_cust_asset_acct.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_prod_asset_list.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_retailer_principal_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_retailer_acc_principal_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_huge_redeem_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_principal_trade_list_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_acct_trade_list_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_special_trade_list_note.json
# 理财客户
# 理财产品开发控制表
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_research_app_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_design_app_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_schedule_app_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_edit_log.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_open_duration_rule.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_task_role_info.json
# 理财产品开发信息
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_register_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_trade_ctl.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_channel.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_issue_area.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_base_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_point_info.json
# 理财产品运营信息
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_reservation_buy_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_buy_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_open_duration_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_redeem_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_dividend_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_netvalue_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_fix_profit_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_fix_period_profit_rat.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_scale_profit_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_fel_period_profit.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_fel_sell_fee_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_fix_sell_fee_rate.json
# 要素变更
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_c_statistics_para.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_change_sheet_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_change_base_para.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_c_felperiod_profit_r.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_c_fixperiod_profit_r.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_c_fixsell_fee.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_c_fix_profit_r.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_c_scale_profit_r.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_change_dividend_para.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_prod_change_netvalue_para.json
# 公共管理
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_public_serial.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_dict.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_oper_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_dept_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_sublicense_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_role_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_role_fun.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_review_main.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_review_sublist.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_area_organ_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_approve_model.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_file_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_trade_time.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_param_validity.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_period_min_rate.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_menu_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_log_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_imp_template.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_short_menu_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_err_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/web_msg.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_instruction_info.json
# 日终处理
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_sellfee_daily.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_sellfee_month.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_trusteefee_daily.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_trusteefee_month.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_retailer_daily_trade_note.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_endday_ctl.json
# 信息统计
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_recom_detail_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_fee_sum_info.json
# 资金划拨
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_pub_acct_std_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_send_data_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_recv_capital_data_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_fee_sum_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_oper_profit_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_sk_notify_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_hk_notify_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_prod_acct_info.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/ta_in_out_acct_ref.json
# 表空间
# 主键
# 索引
# 字段
# ./project_data/tables_json/gf_hb_notify_app.json
