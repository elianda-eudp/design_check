# %%
from docx import Document

def table(num,document):

    row1_list = []
    row_content = []
    """获取第一个表格内容"""
    table = document.tables[num]
    """获取第一行标题"""
    row_1 = table.row_cells(0)
    """将第一行标题提取出来"""
    for row in table.rows:
        for cell1 in row.cells:
    #            print(cell.text)
            for cell2 in row_1:
#                print(cell2.text)
                if cell1.text == cell2.text:
                    key = cell1.text                 
                    row1_list.append(key)
#                    print(key)
                    break
            else:
                """将内容提取出来"""
                value = cell1.text
                new_value = value.replace('\n', ' ')
                row_content.append(new_value)

    dict1={}

    for i in range(len(row1_list)): # 循环标题列表
        dict2={}
        a_list=[j for j in range(i,len(row_content),len(row1_list)) ] # 循环内容列表
        for k in range(len(a_list)):  
            dict2[row1_list[i]+str(k)] = row_content[a_list[k]] # 构造内层字典
        dict1[row1_list[i]] = dict2     # 构造整体字典
              
#    print(dict1)
    return dict1

# %%
def head2_index_get(paras,max_i,min_i):
    head2_index_list=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Heading 2':
            head2_index_list.append(i)
    return head2_index_list

def head3_index_get(paras,max_i,min_i):
    head3_index_list=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Heading 3':
            head3_index_list.append(i)
    return head3_index_list

def head4_index_get(paras,max_i,min_i):
    head4_index_list=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Heading 4':
            head4_index_list.append(i)
    return head4_index_list

def print_con(paras,index):
    for i in index:
        print("    " + paras[i].text)
        
def normal_get(paras,max_i,min_i):
    list_normat=[]
    for i in range(min_i,max_i,1):
        if paras[i].style.name == 'Normal':
            list_normat.append(paras[i].text)
    return list_normat

# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Jan 12 09:55:52 2018

@author: user
"""

from docx import Document
import json
def main(doc='../../../project_data/doc/示例详细设计.doc'):
    document = Document(doc)
    paras = document.paragraphs
    lcount = []  # 存储所有段落的对象 
    tables=0
    
    for i in range(len(paras)):
        if paras[i].style.name == 'Heading 1':
            lcount.append(i)
#            print(paras[i].text)
#    print(len(lcount))      
    # 提取每一段的数据
    for i in range(len(lcount)):
        ax = lcount[i]
        if i>=len(lcount)-1:
            bx = lcount[i]
        else:
            bx = lcount[i+1]
        head1_dict={}
        head2_dict={}
        head2_index_list=head2_index_get(paras,bx,ax)
        #print_con(paras,head2_index_list)
        for j in range(len(head2_index_list)):
            head2_min = head2_index_list[j]
            if j >= len(head2_index_list)-1:
                head2_max = head2_index_list[j]
            else:
                head2_max = head2_index_list[j+1]
            head3_index_list=head3_index_get(paras,head2_max,head2_min)
            
            #print(paras[head2_min].text)
            #print_con(paras,head3_index_list)
            if '调用方法' in str(paras[head2_min].text) :
                    table_dict=table(tables,document)
                    tables+=1
                    head2_dict[paras[head2_min].text]=table_dict
            elif '功能描述' in str(paras[head2_min].text) :
                    normal=normal_get(paras,head2_max,head2_min)
                    head2_dict[paras[head2_min].text]=''.join(normal).replace('\u3000', ' ')
            else:
                head3_dict={}
                for z in range(len(head3_index_list)):
                    head3_min = head3_index_list[z]
                    if z>=len(head3_index_list)-1:
                        head3_max = head3_index_list[z]
                    else:
                        head3_max = head3_index_list[z+1]
                    #print(paras[head3_min].text)
                    if '文件格式' in str(paras[head3_min].text) :
                        #for k in range(head4_min,head4_max):
                         #   print(paras[k].text)
                        table_dict=table(tables,document)
                        tables+=1
                        head3_dict[paras[head3_min].text]=table_dict
                    elif '文件头' in str(paras[head3_min].text) :
                        #for k in range(head4_min,head4_max):
                         #   print(paras[k].text)
                        table_dict=table(tables,document)
                        tables+=1
                        head3_dict[paras[head3_min].text]=table_dict
                    elif '文件体' in str(paras[head3_min].text) :
                        #for k in range(head4_min,head4_max):
                         #   print(paras[k].text)
                        table_dict=table(tables,document)
                        tables+=1
                        head3_dict[paras[head3_min].text]=table_dict
                    elif 'Table--' in str(paras[head3_min].text) :
                        #for k in range(head4_min,head4_max):
                         #   print(paras[k].text)
                        #print(paras[head3_min].text)
                        table_dict=table(tables,document)
                        tables+=1
                        head3_dict[paras[head3_min].text]=table_dict
                        #print(table_dict)
                    else:
                        normal=normal_get(paras,head3_max,head3_min)
                        head3_dict[paras[head3_min].text]=''.join(normal).replace('\u3000', ' ')
                head2_dict[paras[head2_min].text]=head3_dict
            
        head1_dict[paras[ax].text]=head2_dict
        print(head1_dict)
            
        pro_name=paras[ax].text
        file_name='../../../project_data/programs_json/'+pro_name+'.json'
        #print(file_name)
        with open(file_name,'w+') as f:
            str_data = json.dumps(head1_dict)
            f.write(str_data)

# %%
main()
# Out:
# {'程序名称(sql_to_csv)': {'功能描述:': '该功能实现将数据库中的某一张表中的某几条记录导为csv文件，支持全部的数据导出。', '调用方法:': {'参数标识': {'参数标识0': 't', '参数标识1': 'p', '参数标识2': 'c', '参数标识3': 'x', '参数标识4': 'm'}, '是否可选': {'是否可选0': 'Y', '是否可选1': 'N', '是否可选2': 'N', '是否可选3': 'N', '是否可选4': 'y'}, '参数变量': {'参数变量0': 'table_name', '参数变量1': 'out_file_path', '参数变量2': 'code', '参数变量3': 'xode', '参数变量4': 'yode'}, '变量类型': {'变量类型0': 'Char(200)', '变量类型1': 'Char(1024)', '变量类型2': 'Char(8)', '变量类型3': 'bool(8)', '变量类型4': 'bool(8)'}, '说明': {'说明0': '准备导出的表名', '说明1': '输出文件的路径', '说明2': '测试代码', '说明3': 'bool测试代码', '说明4': 'bool测试代码'}}, '输入文件:': {'文件名称(sql_to_csv_input_file)': '', '文件说明': '--.csv逗号分隔值格式文件，可用excel工具打开，显示格式和excel一样..', '文件格式': {'文件类型': {'文件类型0': 'xml'}, '分隔符': {'分隔符0': '|+|'}, '有无文件头': {'有无文件头0': '有'}, '备注': {'备注0': ''}}, '文件头': {'字段名称': {'字段名称0': 'organ_code', '字段名称1': 'oper_code', '字段名称2': 'retailer_code', '字段名称3': 'trade_date', '字段名称4': 'trade_time', '字段名称5': 'acct_serial', '字段名称6': 'timing_buy_agree_code', '字段名称7': 'ta_code', '字段名称8': 'prod_code', '字段名称9': 'per_buy_amt', '字段名称10': 'per_buy_date', '字段名称11': 'period_type', '字段名称12': 'period_length', '字段名称13': 'buy_times', '字段名称14': 'buy_times_postpone', '字段名称15': 'handled_times', '字段名称16': 'fail_handled_times', '字段名称17': 'sum_amt', '字段名称18': 'next_handle_date', '字段名称19': 'cust_mgr_code', '字段名称20': 'channel_no', '字段名称21': 'valid_status', '字段名称22': 'duration_period', '字段名称23': 'host_note', '字段名称24': 'host_code', '字段名称25': 'total_count'}, '字段类型': {'字段类型0': 'CHAR (8) ', '字段类型1': 'CHAR (11) ', '字段类型2': 'CHAR (10) ', '字段类型3': 'CHAR (8)', '字段类型4': 'CHAR (6) ', '字段类型5': 'CHAR (10) ', '字段类型6': 'CHAR (20) ', '字段类型7': 'CHAR (15) ', '字段类型8': 'CHAR (10) ', '字段类型9': 'double(16,2) ', '字段类型10': 'CHAR (8) ', '字段类型11': 'CHAR (2) ', '字段类型12': 'int(3) ', '字段类型13': 'int(7) ', '字段类型14': 'CHAR(1) ', '字段类型15': 'int(7)', '字段类型16': 'int(7)', '字段类型17': 'double (16,2)', '字段类型18': 'CHAR (8) ', '字段类型19': 'CHAR (11)', '字段类型20': 'CHAR (2) ', '字段类型21': 'CHAR(1) ', '字段类型22': 'int(7)', '字段类型23': 'CHAR (128)', '字段类型24': 'CHAR (6)  ', '字段类型25': 'CHAR (6)'}, '说明': {'说明0': '机构代码', '说明1': '操作员代码', '说明2': '销售商代码', '说明3': '交易日期', '说明4': '交易时间', '说明5': '流水号', '说明6': '定投协议号', '说明7': 'TA账号', '说明8': '理财产品编码', '说明9': '每次购买金额', '说明10': '首次购买日期', '说明11': '约定周期类型', '说明12': '约定周期', '说明13': '购买次数', '说明14': '购买次数顺延', '说明15': '已处理次数', '说明16': '已失败处理次数', '说明17': '累计扣款金额', '说明18': '下次处理时间', '说明19': '理财经理号', '说明20': '交易渠道', '说明21': '状态', '说明22': '存续周期', '说明23': ' 主机消息', '说明24': ' 主机返回码', '说明25': '总记录数'}}, '文件体': {'字段名称': {'字段名称0': 'organ_code', '字段名称1': 'oper_code', '字段名称2': 'retailer_code', '字段名称3': 'trade_date', '字段名称4': 'trade_time', '字段名称5': 'acct_serial', '字段名称6': 'timing_buy_agree_code', '字段名称7': 'ta_code', '字段名称8': 'prod_code', '字段名称9': 'per_buy_amt', '字段名称10': 'per_buy_date', '字段名称11': 'period_type', '字段名称12': 'period_length', '字段名称13': 'buy_times', '字段名称14': 'buy_times_postpone', '字段名称15': 'handled_times', '字段名称16': 'fail_handled_times', '字段名称17': 'sum_amt', '字段名称18': 'next_handle_date', '字段名称19': 'cust_mgr_code', '字段名称20': 'channel_no', '字段名称21': 'valid_status', '字段名称22': 'duration_period', '字段名称23': 'host_note', '字段名称24': 'host_code'}, '字段类型': {'字段类型0': 'CHAR (8) ', '字段类型1': 'CHAR (11) ', '字段类型2': 'CHAR (10) ', '字段类型3': 'CHAR (8)', '字段类型4': 'CHAR (6) ', '字段类型5': 'CHAR (10) ', '字段类型6': 'CHAR (20) ', '字段类型7': 'CHAR (15) ', '字段类型8': 'CHAR (10) ', '字段类型9': 'double(16,2) ', '字段类型10': 'CHAR (8) ', '字段类型11': 'CHAR (2) ', '字段类型12': 'int(3) ', '字段类型13': 'int(7) ', '字段类型14': 'CHAR(1) ', '字段类型15': 'int(7)', '字段类型16': 'int(7)', '字段类型17': 'double (16,2)', '字段类型18': 'CHAR (8) ', '字段类型19': 'CHAR (11)', '字段类型20': 'CHAR (2) ', '字段类型21': 'CHAR(1) ', '字段类型22': 'int(7)', '字段类型23': 'CHAR (128)', '字段类型24': 'CHAR (6)  '}, '说明': {'说明0': '机构代码', '说明1': '操作员代码', '说明2': '销售商代码', '说明3': '交易日期', '说明4': '交易时间', '说明5': '流水号', '说明6': '定投协议号', '说明7': 'TA账号', '说明8': '理财产品编码', '说明9': '每次购买金额', '说明10': '首次购买日期', '说明11': '约定周期类型', '说明12': '约定周期', '说明13': '购买次数', '说明14': '购买次数顺延', '说明15': '已处理次数', '说明16': '已失败处理次数', ' ...
# {'程序名称(jhye_profit_file_out)': {'功能描述:': '该功能实现理财产品中灵活期限类产品的收益计算时输入文件的导出。', '调用方法:': {'参数标识': {'参数标识0': 'p'}, '是否可选': {'是否可选0': 'Y'}, '参数变量': {'参数变量0': 'prod_code'}, '变量类型': {'变量类型0': 'Char(10)'}, '说明': {'说明0': '理财产品代码'}}, '输入文件:': {'文件名称()': '', '文件说明': '--.csv逗号分隔值格式文件，可用excel工具打开，显示格式和excel一样..', '文件格式': {'': {}}, '文件头': {'': {}}, '文件体': {'': {}}}, '输出文件：': {'文件名称(load_mv_ta_prod_asset_list_i)': '', '文件说明': '--.csv逗号分隔值格式文件，可用excel工具打开，显示格式和excel一样..', '文件格式': {'文件类型': {'文件类型0': 'xml'}, '分隔符': {'分隔符0': '|'}, '有无文件头': {'有无文件头0': '1'}, '备注': {'备注0': ''}}, '文件头': {'字段名称': {'字段名称0': 'total_count'}, '字段类型': {'字段类型0': 'CHAR (6)'}, '说明': {'说明0': '总记录数'}}, '文件体': {'字段名称': {'字段名称0': 'contract_no', '字段名称1': 'ta_code', '字段名称2': 'prod_code', '字段名称3': 'retailer_code', '字段名称4': 'cust_type', '字段名称5': 'total_quot', '字段名称6': 'available_quot', '字段名称7': 'stop_quot', '字段名称8': 'freeze_quot', '字段名称9': 'currency', '字段名称10': 'duration_period', '字段名称11': 'profit_count_date', '字段名称12': 'organ_code', '字段名称13': 'prov_code', '字段名称14': 'first_buy_amt', '字段名称15': 'net_value'}, '字段类型': {'字段类型0': 'Char(20)', '字段类型1': 'Char(15)', '字段类型2': 'Char(10)', '字段类型3': 'Char(10)', '字段类型4': 'Char(1)', '字段类型5': 'double(16,2)', '字段类型6': 'double(16,2)', '字段类型7': 'double(16,2)', '字段类型8': 'double(16,2)', '字段类型9': 'Char(3)', '字段类型10': 'int(7)', '字段类型11': 'Char(8)', '字段类型12': 'Char(8)', '字段类型13': 'Char(8)', '字段类型14': 'double(16,2)', '字段类型15': 'double(16,8)'}, '说明': {'说明0': '理财合同号', '说明1': 'TA账号', '说明2': '理财产品编码', '说明3': '销售商代码', '说明4': '客户类型', '说明5': '总份额', '说明6': '可用份额', '说明7': '止付份额', '说明8': '冻结份额', '说明9': '币种', '说明10': '存续周期', '说明11': '收益起算日期', '说明12': '机构代码', '说明13': '省代码', '说明14': '最初购买金额', '说明15': '净值'}}}, '数据表': {'Table--理财产品基本信息表(gf_prod_base_info) ': {'序号': {'序号0': '1'}, '操作类型': {'操作类型0': '查询'}, '操作字段': {'操作字段0': 'prod_code'}, '条件字段': {'条件字段0': 'prod_code'}, '排序字段': {'排序字段0': ''}, '备注': {'备注0': ''}}, 'Table--客户理财产品明细表(ta_prod_asset_list) ': {'序号': {'序号0': '1'}, '操作类型': {'操作类型0': '查询'}, '操作字段': {'操作字段0': 'prod_code'}, '条件字段': {'条件字段0': 'prod_code'}, '排序字段': {'排序字段0': ''}, '备注': {'备注0': ''}}, 'Table—机构表(fd_organ) ': ''}, '日志': {'日志输出级别': ''}, '运行时机': {'时点依赖：': '   A、年末/季末/月末/日终：时/分   B、不得晚于XX时/XX分   C、必须在XX时－XX时之间', '事件依赖：': '   A、在XX程序成功执行后运行', '文件依赖：': ''}, '业务处理': {}}}
# {'程序名称(jhye_profit_calc)': {'功能描述:': '该功能实现理财产品中灵活期限类产品的收益计算。', '调用方法:': {'序号': {'序号0': '1'}, '操作类型': {'操作类型0': '查询'}, '操作字段': {'操作字段0': 'Thiscode'}, '条件字段': {'条件字段0': 'Thiscode'}, '排序字段': {'排序字段0': ''}, '备注': {'备注0': ''}}, '输入文件:': {'文件名称(load_mv_ta_prod_asset_list_i)': '', '文件说明': '--.csv逗号分隔值格式文件，可用excel工具打开，显示格式和excel一样..', '文件格式': {'参数标识': {'参数标识0': 'p'}, '是否可选': {'是否可选0': 'Y'}, '参数变量': {'参数变量0': 'prod_code'}, '变量类型': {'变量类型0': 'Char(10)'}, '说明': {'说明0': '理财产品代码'}}, '文件头': {'文件类型': {'文件类型0': 'xml'}, '分隔符': {'分隔符0': '|'}, '有无文件头': {'有无文件头0': '有'}, '备注': {'备注0': ''}}, '文件体': {'字段名称': {'字段名称0': 'total_count'}, '字段类型': {'字段类型0': 'CHAR (6)'}, '说明': {'说明0': '总记录数'}}}, '输出文件：': {'文件名称(load_mv_ta_prod_asset_list_o)': '', '文件说明': '--.csv逗号分隔值格式文件，可用excel工具打开，显示格式和excel一样..', '文件格式': {'字段名称': {'字段名称0': 'contract_no', '字段名称1': 'ta_code', '字段名称2': 'prod_code', '字段名称3': 'retailer_code', '字段名称4': 'cust_type', '字段名称5': 'total_quot', '字段名称6': 'available_quot', '字段名称7': 'stop_quot', '字段名称8': 'freeze_quot', '字段名称9': 'currency', '字段名称10': 'duration_period', '字段名称11': 'profit_count_date', '字段名称12': 'organ_code', '字段名称13': 'prov_code', '字段名称14': 'first_buy_amt', '字段名称15': 'net_value'}, '字段类型': {'字段类型0': 'Char(20)', '字段类型1': 'Char(15)', '字段类型2': 'Char(10)', '字段类型3': 'Char(10)', '字段类型4': 'Char(1)', '字段类型5': 'double(16,2)', '字段类型6': 'double(16,2)', '字段类型7': 'double(16,2)', '字段类型8': 'double(16,2)', '字段类型9': 'Char(3)', '字段类型10': 'int(7)', '字段类型11': 'Char(8)', '字段类型12': 'Char(8)', '字段类型13': 'Char(8)', '字段类型14': 'double(16,2)', '字段类型15': 'double(16,8)'}, '说明': {'说明0': '理财合同号', '说明1': 'TA账号', '说明2': '理财产品编码', '说明3': '销售商代码', '说明4': '客户类型', '说明5': '总份额', '说明6': '可用份额', '说明7': '止付份额', '说明8': '冻结份额', '说明9': '币种', '说明10': '存续周期', '说明11': '收益起算日期', '说明12': '机构代码', '说明13': '省代码', '说明14': '最初购买金额', '说明15': '净值'}}, '文件头': {'文件类型': {'文件类型0': 'xml'}, '分隔符': {'分隔符0': '|+|'}, '有无文件头': {'有无文件头0': '1'}, '备注': {'备注0': ''}}, '文件体': {'字段名称': {'字段名称0': 'total_count'}, '字段类型': {'字段类型0': 'CHAR (6)'}, '说明': {'说明0': '总记录数'}}}, '数据表': {'Table--理财产品灵活期限收益组合类信息(gf_prod_fel_period_profit_rate) ': {'字段名称': {'字段名称0': 'trade_date', '字段名称1': 'ta_code', '字段名称2': 'application_code', '字段名称3': 'prod_code', '字段名称4': 'daily_quot', '字段名称5': 'daily_profit', '字段名称6': 'sum_profit', '字段名称7': 'cust_type', '字段名称8': 'hold_days'}, '字段类型': {'字段类型0': 'Char(8)', '字段类型1': 'Char(15)', '字段类型2': 'Char(20)', '字段类型3': 'Char(10)', '字段类型4': 'double(22,2)', '字段类型5': 'double(22,2)', '字段类型6': 'double(22,2)', '字段类型7': 'Char(1)', '字段类型8': 'int'}, '说明': {'说明0': '交易日期', '说明1': 'TA账号', '说明2': '申请单编号', '说明3': '理财产品编码', '说明4': '当日保有量', '说明5': '当日收益', '说明6': '累计收益', '说明7': '客户类型', '说明8': '持有天数'}}, 'Table--理财产品基本信息表(gf_prod_base_info) ': {'序号': {'序号0': '1'}, '操作类型': {'操作类型0': '查询'}, '操作字段': {'操作字段0': 'prod_code organ_code period_low period_high profit_rate begin_date cust_type'}, '条件字段': {'条件字段0': 'prod_code valid_status'}, '排序字段': {'排序字段0': 'cust_type organ_code period_high begin_date'}, '备注': {'备注0': ''}}, 'Table--客户理财产品明细表(ta_prod_asset_list) ': {'序号': {'序号0': '1'}, '操作类型': {'操作类型0': '查询'}, '操作字段': {'操作字段0': 'prod_code'}, '条件字段': {'条件字段0': 'prod_code'}, '排序字段': {'排序字段0': ''}, '备注': {'备注0': ''}}}, '日志': {'日志输出级别': ''}, '运行时机': {'时点依赖：': '   A、年末/季末/月末/日终：时/分   B、不得晚于XX时/XX分   C、必须在XX时－XX时之间', '事件依赖：': '   A、在XX程序成功执行后运行', '文件依赖：': ''}, '业务处理': {}}}
# {'程序名称(jhye_profit_file_in)': {'功能描述:': '该功能实现理财产品中灵活期限类产品的收益计算完成后计入数据库。', '调用方法:': {'序号': {'序号0': '1'}, '操作类型': {'操作类型0': '查询'}, '操作字段': {'操作字段0': 'prod_code'}, '条件字段': {'条件字段0': 'prod_code'}, '排序字段': {'排序字段0': ''}, '备注': {'备注0': ''}}, '输入文件:': {'文件名称(load_mv_ta_prod_asset_list_o)': '', '文件说明': '--.csv逗号分隔值格式文件，可用excel工具打开，显示格式和excel一样..', '文件格式': {'参数标识': {'参数标识0': 'P'}, '是否可选': {'是否可选0': 'Y'}, '参数变量': {'参数变量0': 'prod_code'}, '变量类型': {'变量类型0': 'Char(10)'}, '说明': {'说明0': '理财产品代码'}}, '文件头': {'文件类型': {'文件类型0': 'Xml'}, '分隔符': {'分隔符0': '|+|'}, '有无文件头': {'有无文件头0': '有'}, '备注': {'备注0': ''}}, '文件体': {'字段名称': {'字段名称0': 'total_count'}, '字段类型': {'字段类型0': 'CHAR (6)'}, '说明': {'说明0': '总记录数'}}}, '输出文件：': {'文件名称()': '', '文件说明': '--.csv逗号分隔值格式文件，可用excel工具打开，显示格式和excel一样..', '文件格式': {'字段名称': {'字段名称0': 'trade_date', '字段名称1': 'ta_code', '字段名称2': 'application_code', '字段名称3': 'prod_code', '字段名称4': 'daily_quot', '字段名称5': 'daily_profit', '字段名称6': 'sum_profit', '字段名称7': 'cust_type', '字段名称8': 'hold_days'}, '字段类型': {'字段类型0': 'Char(8)', '字段类型1': 'Char(15)', '字段类型2': 'Char(20)', '字段类型3': 'Char(10)', '字段类型4': 'double(22,2)', '字段类型5': 'double(22,2)', '字段类型6': 'double(22,2)', '字段类型7': 'Char(1)', '字段类型8': 'int'}, '说明': {'说明0': '交易日期', '说明1': 'TA账号', '说明2': '申请单编号', '说明3': '理财产品编码', '说明4': '当日保有量', '说明5': '当日收益', '说明6': '累计收益', '说明7': '客户类型', '说明8': '持有天数'}}, '文件头': {'文件类型': {'文件类型0': 'xml'}, '分隔符': {'分隔符0': '|+|'}, '有无文件头': {'有无文件头0': '1'}, '备注': {'备注0': ''}}, '文件体': {'字段名称': {'字段名称0': 'total_count'}, '字段类型': {'字段类型0': 'CHAR (6)'}, '说明': {'说明0': '总记录数'}}}, '数据表': {'Table--开放式收益率产品每日收益明细表(gf_prod_profit_detail) ': {'字段名称': {'字段名称0': 'trade_date', '字段名称1': 'ta_code', '字段名称2': 'application_code', '字段名称3': 'prod_code', '字段名称4': 'daily_quot', '字段名称5': 'daily_profit', '字段名称6': 'sum_profit', '字段名称7': 'cust_type', '字段名称8': 'hold_days'}, '字段类型': {'字段类型0': 'Char(8)', '字段类型1': 'Char(15)', '字段类型2': 'Char(20)', '字段类型3': 'Char(10)', '字段类型4': 'double(22,2)', '字段类型5': 'double(22,2)', '字段类型6': 'double(22,2)', '字段类型7': 'Char(1)', '字段类型8': 'int'}, '说明': {'说明0': '交易日期', '说明1': 'TA账号', '说明2': '申请单编号', '说明3': '理财产品编码', '说明4': '当日保有量', '说明5': '当日收益', '说明6': '累计收益', '说明7': '客户类型', '说明8': '持有天数'}}}, '日志': {'日志输出级别': ''}, '运行时机': {'时点依赖：': '   A、年末/季末/月末/日终：时/分   B、不得晚于XX时/XX分   C、必须在XX时－XX时之间', '事件依赖：': '   A、在XX程序成功执行后运行', '文件依赖：': ''}, '业务处理': {}}}
# {'程序名称(jhye_profit)': {'功能描述:': '该功能实现调度上面的程序。', '调用方法:': {'序号': {'序号0': '1'}, '操作类型': {'操作类型0': '插入'}, '操作字段': {'操作字段0': ''}, '条件字段': {'条件字段0': ''}, '排序字段': {'排序字段0': ''}, '备注': {'备注0': ''}}, '输入文件:': {'文件名称()': '', '文件说明': '', '文件格式': {'参数标识': {'参数标识0': 'p'}, '是否可选': {'是否可选0': 'Y'}, '参数变量': {'参数变量0': 'prod_code'}, '变量类型': {'变量类型0': 'Char(10)'}, '说明': {'说明0': '理财产品代码'}}, '文件头': {'': {}}, '文件体': {'': {}}}, '输出文件：': {'文件名称()': '', '文件说明': '', '文件格式': {'': {}}, '文件头': {'': {}}, '文件体': {'': {}}}, '数据表': {'Table--理财产品基本信息表(gf_prod_base_info) ': {'': {}}}, '日志': {'日志输出级别': ''}, '运行时机': {'时点依赖：': '   A、年末/季末/月末/日终：时/分   B、不得晚于XX时/XX分   C、必须在XX时－XX时之间', '事件依赖：': '   A、在XX程序成功执行后运行', '文件依赖：': ''}, '业务处理': {}}}
# {'End': {}}
